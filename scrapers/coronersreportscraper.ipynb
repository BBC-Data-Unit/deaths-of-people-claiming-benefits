# %% [markdown]
# # Scraping coroners' reports
#
# We want to scrape coroners' reports at https://www.judiciary.uk/related-offices-and-bodies/office-chief-coroner/https-www-judiciary-uk-subject-community-health-care-and-emergency-services-related-deaths/
#
# Breaking down the process, we need to do the following:
#
# 1. Scrape the category links on that page
# 2. Go to each category page and scrape the results (name, detail link, categories etc)
# 3. Go to the detail page and scrape the document details (response)
# 4. Find the 'next' page link and repeat
#
# First we install and import the libraries we need:

# %%
#!/usr/bin/env python
# !pip install scraperwiki
import scraperwiki
import lxml.html
# !pip install cssselect
import cssselect
import json
import urllib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scraperwiki
#   Downloading scraperwiki-0.5.1.tar.gz (7.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from scraperwiki) (2.25.1)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from scraperwiki) (1.15.0)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.8/dist-packages (from scraperwiki) (1.4.46)
# Collecting alembic
#   Downloading alembic-1.9.1-py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.4/210.4 KB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from alembic->scraperwiki) (6.0.0)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 KB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from alembic->scraperwiki) (5.10.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.8/dist-packages (from sqlalchemy->scraperwiki) (2.0.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->scraperwiki) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->scraperwiki) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->scraperwiki) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->scraperwiki) (2.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->alembic->scraperwiki) (3.11.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.8/dist-packages (from Mako->alembic->scraperwiki) (2.0.1)
# Building wheels for collected packages: scraperwiki
#   Building wheel for scraperwiki (setup.py) ... done
#   Created wheel for scraperwiki: filename=scraperwiki-0.5.1-py3-none-any.whl size=6543 sha256=78b2315f2713f35033dccefc6c0715ad85a0a69516b45c5b3aa7707379c18871
#   Stored in directory: /root/.cache/pip/wheels/9b/18/cf/a5b4f9182c2f001b76662535e0a806c13e996193eaaf2c9169
# Successfully built scraperwiki
# Installing collected packages: Mako, alembic, scraperwiki
# Successfully installed Mako-1.2.4 alembic-1.9.1 scraperwiki-0.5.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cssselect
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: cssselect
# Successfully installed cssselect-1.2.0

# %% [markdown]
# ## Scraping the links to category pages
#
# We need to store the URL of the starting page and then scrape all the category pages linked from that:

# %%
#store the URL we want to start scraping from
starturl = 'https://www.judiciary.uk/related-offices-and-bodies/office-chief-coroner/https-www-judiciary-uk-subject-community-health-care-and-emergency-services-related-deaths/'

# %%
html = scraperwiki.scrape(starturl)
#convert from a string into an lxml object that can be parsed using lxml functions
root = lxml.html.fromstring(html)
#use the lxml function cssselect to grab any link inside a list inside an <article> tag, which is where the category linksare
catlinks = root.cssselect('article ul li a')
#measure the length of that list of matches, and print it
print ('found ',len(catlinks), ' reports')
# Out:
# found  7  reports

# %%
#Loop through the matches and print the href="" attribute
for link in catlinks:
  print(link.attrib['href'])
# Out:
# https://www.judiciary.uk/courts-and-tribunals/coroners-courts/coroners/
# https://www.judiciary.uk/courts-and-tribunals/coroners-courts/office-chief-coroner/
# https://www.judiciary.uk/courts-and-tribunals/coroners-courts/coroners-legislation-guidance-and-advice/
# https://www.judiciary.uk/courts-and-tribunals/coroners-courts/annual-reports/
# https://www.judiciary.uk/courts-and-tribunals/coroners-courts/judge-led-inquests/
# https://www.judiciary.uk/courts-and-tribunals/coroners-courts/coroners-appointments-contacts-and-areas/
# https://www.judiciary.uk/courts-and-tribunals/coroners-courts/concerns-and-complaints-about-coroners/

# %% [markdown]
# That seems to have worked nicely. We need to store those so we can loop through and scrape each one:

# %%
#create an empty list to store the URLs
caturls = []
#Loop through the matches and print the href="" attribute
for link in catlinks:
  caturls.append(link.attrib['href'])
print(caturls)
# Out:
# ['https://www.judiciary.uk/subject/accident-at-work-and-health-and-safety-related-deaths/', 'https://www.judiciary.uk/subject/alcohol-drug-and-medication-related-deaths/', 'https://www.judiciary.uk/subject/care-home-health-related-deaths/', 'https://www.judiciary.uk/subject/child-death', 'https://www.judiciary.uk/subject/community-health-care-and-emergency-services-related-deaths/', 'https://www.judiciary.uk/subject/emergency-services-related-deaths-prevention-of-future-deaths/', 'https://www.judiciary.uk/subject/hospital-death-clinical-procedures-and-medical-management-related-deaths/', 'https://www.judiciary.uk/subject/mental-health-related-deaths/', 'https://www.judiciary.uk/subject/other-related-deaths/', 'https://www.judiciary.uk/subject/police-related-deaths/', 'https://www.judiciary.uk/subject/product-related-deaths/', 'https://www.judiciary.uk/subject/road-highways-safety-related-deaths/', 'https://www.judiciary.uk/subject/railway-related-deaths/', 'https://www.judiciary.uk/subject/state-custody-related-deaths/', 'https://www.judiciary.uk/subject/suicide/', 'https://www.judiciary.uk/subject/wales-pfd-reports-related-deaths/']

# %% [markdown]
# We now need to create a function to scrape each category page, before letting it loose on all those URLs.
#
# ## Creating a scraper function for category pages

# %%
#create a function to scrape each results page
def scraperesultspage(url):
    #scrape webpage into a variable called 'html'
    html = scraperwiki.scrape(url)
    #convert from a string into an lxml object that can be parsed using lxml functions
    root = lxml.html.fromstring(html)
    #use the lxml function cssselect to grab anything inside an <article> tag, which is where the reports are
    articles = root.cssselect('article')
    #measure the length of that list of results, and print it
    print ('found ',len(articles), ' reports')

#test it
scraperesultspage(caturls[0])
# Out:
# found  10  reports

# %% [markdown]
# 10 results is what we'd expect. Let's extend that scraper to start storing different data points from each report. We create an empty dictionary first to store that data.

# %%
#create an empty dictionary variable to hold our data later
record = {}

#create a function to scrape each results page
def scraperesultspage(url):
    #scrape webpage into a variable called 'html'
    html = scraperwiki.scrape(url)
    #convert from a string into an lxml object that can be parsed using lxml functions
    root = lxml.html.fromstring(html)
    #use the lxml function cssselect to grab anything inside an <article> tag, which is where the reports are
    articles = root.cssselect('article')
    #measure the length of that list of results, and print it
    print ('found ',len(articles), ' reports')
    #loop through each match in the list
    for article in articles:
        #grab the heading 5 tags with links
        links = article.cssselect('h5 a')
        #There should only be one, so we grab the text of that and store in the dictionary variable 'record'
        record['title'] = links[0].text_content()
        #print the data so far
        print(record)
        #grab the link attribute and store 
        record['reporturl'] = links[0].attrib['href']
        #grab the <time> tags
        times = article.cssselect('time')
        #there's only 1, grab the text content of that
        record['time'] = times[0].text_content()
        #grab the datetime= attribute, this is more specifically encoded
        record['timestamp'] = times[0].attrib['datetime']
        #grab all the <span> tags - there should be 4
        spans = article.cssselect('span a')
        #sometimes there are more than 4, where multiple categories are used, so we create an empty variable...
        categories = ""
        #...and loop through all the spans, adding them together with a semi-colon separator
        for span in spans:
            categories = categories+";"+span.text_content()
        #print categories
        #next we clean them up by replacing the redundant text content which doesn't refer to categories
        categoriescleaned = categories.replace('Prevention of Future Deaths','').replace('PFD Report','').replace('Coroner','').replace(';;','') #the double semi-colon is left over from when they were added
        #print categoriescleaned
        record['categories'] = categoriescleaned
        #This should always be 4, but we're storing it in case there are occasions when there are more, in which case we need to adapt the scraper
        record['spans'] = len(spans)
        print('test', record)
        #the summary is in <div class="entry-summary"> so this grabs any matches
        summaries = article.cssselect('div.entry-summary')
        #store the full text of the first (and only) match in a variable called 'summary'
        summary = summaries[0].text_content()
        print('summary: ', summary)
        print(len(summaries))
        #split it on key phrases and store results
        #at some point spaces are replaced with &nbsp; so we can't use spaces in the splits
        record['reportdate'] = summary.split('Date of report:')[1].split('Ref:')[0]
        #FORK TO GO HERE
        #Store the data
        scraperwiki.sql.save(['reporturl'],record, table_name = "test1") 

#test it
scraperesultspage(caturls[1])
# Out:
# found  10  reports
# {'title': 'Daniel Coleman'}
# test {'title': 'Daniel Coleman', 'reporturl': 'https://www.judiciary.uk/publications/daniel-coleman/', 'time': '26 October 2020', 'timestamp': '2020-10-26T17:33:42+00:00', 'categories': 'Alcohol, drug and medication related deaths;Other related deaths', 'spans': 5}
# summary:
#     Date of report: 25 August 2020 Ref: 2020-0166 Deceased name: Daniel Coleman Coroner name: M E Hassell Coroner Area: Inner North London Category: Alcohol, drug and medication related deaths; Other related deaths This report is ...
# 1
# {'title': 'Toby Nieland', 'reporturl': 'https://www.judiciary.uk/publications/daniel-coleman/', 'time': '26 October 2020', 'timestamp': '2020-10-26T17:33:42+00:00', 'categories': 'Alcohol, drug and medication related deaths;Other related deaths', 'spans': 5, 'reportdate': ' 25 August 2020 '}
# test {'title': 'Toby Nieland', 'reporturl': 'https://www.judiciary.uk/publications/toby-nieland/', 'time': '26 October 2020', 'timestamp': '2020-10-26T16:51:34+00:00', 'categories': 'Alcohol, drug and medication related deaths;Community health care and emergency services related deaths;Mental Health related deaths', 'spans': 6, 'reportdate': ' 25 August 2020 '}
# summary:
#     Date of report: 26 August 2020 Ref: 2020-0164 Deceased name: Toby Nieland Coroner name: Timothy Brennand Coroner Area: Lincolnshire Category: Alcohol, drug and medication related deaths; Community healthcare related deaths; Mental health related deaths This ...
# 1
# {'title': 'Ian Allen', 'reporturl': 'https://www.judiciary.uk/publications/toby-nieland/', 'time': '26 October 2020', 'timestamp': '2020-10-26T16:51:34+00:00', 'categories': 'Alcohol, drug and medication related deaths;Community health care and emergency services related deaths;Mental Health related deaths', 'spans': 6, 'reportdate': ' 26 August 2020 '}
# test {'title': 'Ian Allen', 'reporturl': 'https://www.judiciary.uk/publications/ian-allen/', 'time': '26 October 2020', 'timestamp': '2020-10-26T14:32:57+00:00', 'categories': 'Alcohol, drug and medication related deaths;Care Home Health related deaths', 'spans': 5, 'reportdate': ' 26 August 2020 '}
# summary:
#     Date of report: 17 August 2020 Ref: 2020-0161 Deceased name: Ian Allen Coroner name: Louise Hunt Coroner Area: Birmingham and Solihull Category: Care Home health deaths; Alcohol, drug and medication related deaths This report is ...
# 1
# {'title': 'Theresa Robertson', 'reporturl': 'https://www.judiciary.uk/publications/ian-allen/', 'time': '26 October 2020', 'timestamp': '2020-10-26T14:32:57+00:00', 'categories': 'Alcohol, drug and medication related deaths;Care Home Health related deaths', 'spans': 5, 'reportdate': ' 17 August 2020 '}
# test {'title': 'Theresa Robertson', 'reporturl': 'https://www.judiciary.uk/publications/theresa-robertson/', 'time': '22 October 2020', 'timestamp': '2020-10-22T09:58:24+01:00', 'categories': 'Alcohol, drug and medication related deaths;Community health care and emergency services related deaths', 'spans': 5, 'reportdate': ' 17 August 2020 '}
# summary:
#     Date of report: 6 August 2020 Ref: 2020-0158 Deceased name: Theresa Robertson Coroner name: Graeme Irvine Coroner Area: East London Category: Alcohol, drug and medication related deaths; Community healthcare related deaths This report is being ...
# 1
# {'title': 'Alana Cutland', 'reporturl': 'https://www.judiciary.uk/publications/theresa-robertson/', 'time': '22 October 2020', 'timestamp': '2020-10-22T09:58:24+01:00', 'categories': 'Alcohol, drug and medication related deaths;Community health care and emergency services related deaths', 'spans': 5, 'reportdate': ' 6 August 2020 '}
# test {'title': 'Alana Cutland', 'reporturl': 'https://www.judiciary.uk/publications/alana-cutland/', 'time': '19 October 2020', 'timestamp': '2020-10-19T09:17:05+01:00', 'categories': 'Alcohol, drug and medication related deaths;Other related deaths', 'spans': 5, 'reportdate': ' 6 August 2020 '}
# summary:
#     Date of report: 5 August 2020 Ref: 2020-0151 Deceased name: Alana Cutland Coroner name: Tom Osborne Coroner Area: Milton Keynes Category: Alcohol, drug and medication related deaths; Other related deaths This report is being sent ...
# 1
# {'title': 'Pauline Russell', 'reporturl': 'https://www.judiciary.uk/publications/alana-cutland/', 'time': '19 October 2020', 'timestamp': '2020-10-19T09:17:05+01:00', 'categories': 'Alcohol, drug and medication related deaths;Other related deaths', 'spans': 5, 'reportdate': ' 5 August 2020 '}
# test {'title': 'Pauline Russell', 'reporturl': 'https://www.judiciary.uk/publications/pauline-russell/', 'time': '16 October 2020', 'timestamp': '2020-10-16T11:34:53+01:00', 'categories': 'Alcohol, drug and medication related deaths;Hospital Death (Clinical Procedures and medical management) related deaths', 'spans': 5, 'reportdate': ' 5 August 2020 '}
# summary:
#     Date of report: 4 August 2020 Ref: 2020-0149 Deceased name: Pauline Russell Coroner name: Yvonne Blake Coroner Area: Norfolk Category: Alcohol, drug and medication related deaths; Hospital death (clinical procedures and medical management) related deaths ...
# 1
# {'title': 'Amy Hogan', 'reporturl': 'https://www.judiciary.uk/publications/pauline-russell/', 'time': '16 October 2020', 'timestamp': '2020-10-16T11:34:53+01:00', 'categories': 'Alcohol, drug and medication related deaths;Hospital Death (Clinical Procedures and medical management) related deaths', 'spans': 5, 'reportdate': ' 4 August 2020 '}
# test {'title': 'Amy Hogan', 'reporturl': 'https://www.judiciary.uk/publications/amy-hogan/', 'time': '7 October 2020', 'timestamp': '2020-10-07T12:31:27+01:00', 'categories': 'Alcohol, drug and medication related deaths;Community health care and emergency services related deaths', 'spans': 5, 'reportdate': ' 4 August 2020 '}
# summary:
#     Date of report: 31 July 2020 Ref: 2020-0147 Deceased name: Amy Hogan Coroner name: Christopher Morris Coroner Area: Manchester South Category: Alcohol, drug and medication related deaths; Community healthcare related deaths This report is being ...
# 1
# {'title': 'Jerrelle McKenzie', 'reporturl': 'https://www.judiciary.uk/publications/amy-hogan/', 'time': '7 October 2020', 'timestamp': '2020-10-07T12:31:27+01:00', 'categories': 'Alcohol, drug and medication related deaths;Community health care and emergency services related deaths', 'spans': 5, 'reportdate': ' 31 July 2020 '}
# test {'title': 'Jerrelle McKenzie', 'reporturl': 'https://www.judiciary.uk/publications/jerrelle-mckenzie/', 'time': '1 October 2020', 'timestamp': '2020-10-01T14:21:58+01:00', 'categories': 'Alcohol, drug and medication related deaths', 'spans': 4, 'reportdate': ' 31 July 2020 '}
# summary:
#     Date of report: 17 July 2020 Ref: 2020-0144 Deceased name: Jerrelle McKenzie Coroner name: Emma Whitting Coroner Area: Bedfordshire and Luton Category: Alcohol, drug and medication related deaths This report is being sent to: Secretary ...
# 1
# {'title': 'Sophie Boothe', 'reporturl': 'https://www.judiciary.uk/publications/jerrelle-mckenzie/', 'time': '1 October 2020', 'timestamp': '2020-10-01T14:21:58+01:00', 'categories': 'Alcohol, drug and medication related deaths', 'spans': 4, 'reportdate': ' 17 July 2020 '}
# test {'title': 'Sophie Boothe', 'reporturl': 'https://www.judiciary.uk/publications/sophie-boothe/', 'time': '1 October 2020', 'timestamp': '2020-10-01T12:15:36+01:00', 'categories': 'Alcohol, drug and medication related deaths;Mental Health related deaths', 'spans': 5, 'reportdate': ' 17 July 2020 '}
# summary:
#     Date of report: 2 March 2020 Ref: 2020-0142 Deceased name: Sophie Boothe Coroner name: Samantha Marsh Coroner Area: Hampshire (Central) Category: Mental Health related deaths; Alcohol, drug and medication related deaths This report is being ...
# 1
# {'title': 'Liane Davenport', 'reporturl': 'https://www.judiciary.uk/publications/sophie-boothe/', 'time': '1 October 2020', 'timestamp': '2020-10-01T12:15:36+01:00', 'categories': 'Alcohol, drug and medication related deaths;Mental Health related deaths', 'spans': 5, 'reportdate': ' 2 March 2020 '}
# test {'title': 'Liane Davenport', 'reporturl': 'https://www.judiciary.uk/publications/liane-davenport/', 'time': '21 September 2020', 'timestamp': '2020-09-21T13:03:57+01:00', 'categories': 'Alcohol, drug and medication related deaths;Mental Health related deaths', 'spans': 5, 'reportdate': ' 2 March 2020 '}
# summary:
#     Date of report: 10 October 2019 Ref: 2020-0136 Deceased name: Liane Davenport Coroner name: Kally Cheema Coroner Area: Cumbria Category: Mental Health related deaths; Alcohol, drug and medication related deaths This report is being sent ...
# 1

# %% [markdown]
# ## RETHINK: Going through the 'coroners' page and focusing on detail pages
#
# At this point I notice that there's a 'Coroners' link which takes you to a page which appears to have *all* coroner reports in all categories: https://www.judiciary.uk/publication-jurisdiction/coroner/
#
# I also realise that if we're going to grab details on the responses then it will be simpler to skip the results pages and only scrape the detail pages instead.
#
# So the process is now:
#
# 1. Write a scraper for the detail page
# 2. Write a scraper for the 'all reports' page, which also goes to each 'next' page, and grabs each detail link, then runs the first scraper on the page at that link

# %% [markdown]
# ## Creating a new function to scrape the detail pages
#
# We begin by scraping the detail page. Later we can create a scraper to fetch the URLs of all the detail pages and run this function on those.

# %%
def scrapedetail(detailurl):
  #scrape webpage into a variable called 'html'
  html = scraperwiki.scrape(detailurl)
  #convert from a string into an lxml object that can be parsed using lxml functions
  root = lxml.html.fromstring(html)
  #use the lxml function cssselect to grab anything inside an <article> tag, which is where the reports are
  articles = root.cssselect('article')
  #measure the length of that list of results, and print it
  print ('found ',len(articles), ' reports')

#Test
scrapedetail("https://www.judiciary.uk/publications/kerry-aldridge/")
# Out:
# found  1  reports

# %% [markdown]
# Now we know it grabs the one `<article>` tag we know contains the info we need, we expand the function further...

# %%
#Create empty record to store data
record = {}

#define the function
def scrapedetail(detailurl):
  #scrape webpage into a variable called 'html'
  html = scraperwiki.scrape(detailurl)
  #convert from a string into an lxml object that can be parsed using lxml functions
  root = lxml.html.fromstring(html)
  #use the lxml function cssselect to grab anything inside an <article> tag, which is where the reports are
  articles = root.cssselect('article')
  #there's only one, so store that
  article = articles[0]
  #grab the <h1> tags with links
  h1s = article.cssselect('h1')
  #There should only be one, so we grab the text of that and store in the dictionary variable 'record'
  record['title'] = h1s[0].text_content()
  #grab the <time> tags
  times = article.cssselect('time')
  #there's only 1, grab the text content of that
  record['time'] = times[0].text_content()
  #grab the datetime= attribute, this is more specifically encoded
  record['timestamp'] = times[0].attrib['datetime']
  print(record)
  #grab all the <span> tags
  spans = article.cssselect('span a')
  #sometimes there are more than 4, where multiple categories are used
  for span in spans:
    print(span.text_content())
  

#Test
scrapedetail("https://www.judiciary.uk/publications/kerry-aldridge/")
# Out:
# {'title': 'Kerry Aldridge', 'time': '18 March 2020', 'timestamp': '2020-03-18T12:51:46+00:00'}
# Prevention of Future Deaths
# Mental Health related deaths
# Railway related deaths
# Suicide (from 2015)
# PFD Report
# Coroner

# %% [markdown]
# ### Handling multiple categories
#
# How do we deal with this list of categories and other information which could be different lengths and different categories?
#
# Firstly, we can remove the PFD Report and Coroner entries because a) they're always there and b) we are only interested in the categories.
#
# There are 2 ways we can do this: by position (they are always the last and penultimate items in the lsit) or by text match (they always use the same text).
#
# What about the remaining categories? We can use the text as the *key* for the dictionary, and set the *value* to true, e.g. `'Prevention of Future Deaths': True`.

# %%
#Create empty record to store data
record = {}

#define the function
def scrapedetail(detailurl):
  #scrape webpage into a variable called 'html'
  html = scraperwiki.scrape(detailurl)
  #convert from a string into an lxml object that can be parsed using lxml functions
  root = lxml.html.fromstring(html)
  #use the lxml function cssselect to grab anything inside an <article> tag, which is where the reports are
  articles = root.cssselect('article')
  #there's only one, so store that
  article = articles[0]
  #grab the <h1> tags with links
  h1s = article.cssselect('h1')
  #There should only be one, so we grab the text of that and store in the dictionary variable 'record'
  record['title'] = h1s[0].text_content()
  #grab the <time> tags
  times = article.cssselect('time')
  #there's only 1, grab the text content of that
  record['time'] = times[0].text_content()
  #grab the datetime= attribute, this is more specifically encoded
  record['timestamp'] = times[0].attrib['datetime']
  print(record)
  #grab all the <span> tags
  spans = article.cssselect('span a')
  #Create an empty list to store the text
  spantext = []
  #loop through the spans and store the text in that list
  for span in spans:
    spantext.append(span.text_content())
  #Remove the two values we don't want
  spantext.remove('PFD Report')
  spantext.remove('Coroner')
  print(spantext)
  for t in spantext:
    record[t] = True
  print(record)
  

#Test
scrapedetail("https://www.judiciary.uk/publications/kerry-aldridge/")
# Out:
# {'title': 'Kerry Aldridge', 'time': '18 March 2020', 'timestamp': '2020-03-18T12:51:46+00:00'}
# ['Prevention of Future Deaths', 'Mental Health related deaths', 'Railway related deaths', 'Suicide (from 2015)']
# {'title': 'Kerry Aldridge', 'time': '18 March 2020', 'timestamp': '2020-03-18T12:51:46+00:00', 'Prevention of Future Deaths': True, 'Mental Health related deaths': True, 'Railway related deaths': True, 'Suicide (from 2015)': True}

# %% [markdown]
# ### Handling the data labels stored as text
#
# This is one approach - another would be to create an existing dictionary of categories set to `False` by default which we switch to `True` if in the list captured by the code.
#
# Meanwhile, we expand the function further to grab the data on reference number, coroner name, recipients, etc.

# %%
#Create empty record to store data
record = {}

#define the function
def scrapedetail(detailurl):
  #scrape webpage into a variable called 'html'
  html = scraperwiki.scrape(detailurl)
  #convert from a string into an lxml object that can be parsed using lxml functions
  root = lxml.html.fromstring(html)
  #use the lxml function cssselect to grab anything inside an <article> tag, which is where the reports are
  articles = root.cssselect('article')
  #there's only one, so store that
  article = articles[0]
  #grab the <h1> tags with links
  h1s = article.cssselect('h1')
  #There should only be one, so we grab the text of that and store in the dictionary variable 'record'
  record['title'] = h1s[0].text_content()
  #grab the <time> tags
  times = article.cssselect('time')
  #there's only 1, grab the text content of that
  record['published'] = times[0].text_content()
  #grab the datetime= attribute, this is more specifically encoded
  record['timestamp'] = times[0].attrib['datetime']
  print(record)
  #grab all the <span> tags
  spans = article.cssselect('span a')
  #Create an empty list to store the text
  spantext = []
  #loop through the spans and store the text in that list
  for span in spans:
    spantext.append(span.text_content())
  #Remove the two values we don't want
  spantext.remove('PFD Report')
  spantext.remove('Coroner')
  print(spantext)
  for t in spantext:
    record[t] = True
  print(record)
  #grab the <p> tags
  ps = article.cssselect('div.entry-content p')
  #Create an empty list to store the text content
  ptexts = []
  #Loop through the p tags and append the text to that list
  for p in ps:
    ptexts.append(p.text_content())
  for t in ptexts:
    #Split into the label (e.g. Ref:) and the value (e.g. Andrew Harris) and store in a list
    tsplit = t.split(": ")
    #this line converts the text label to a key by removing spaces and making it lowercase
    record[tsplit[0].replace(" ","").lower()] = tsplit[1]
    if "This report is being sent to: " in t:
      #Remove the label part and store the list of recipients
      recipients = t.replace("This report is being sent to: ","").split(";")
      #Use each as a key and store the True value against it
      for r in recipients:
        record[r] = True
  print(record)
  

#Test
scrapedetail("https://www.judiciary.uk/publications/kerry-aldridge/")
# Out:
# {'title': 'Kerry Aldridge', 'published': '18 March 2020', 'timestamp': '2020-03-18T12:51:46+00:00'}
# ['Prevention of Future Deaths', 'Mental Health related deaths', 'Railway related deaths', 'Suicide (from 2015)']
# {'title': 'Kerry Aldridge', 'published': '18 March 2020', 'timestamp': '2020-03-18T12:51:46+00:00', 'Prevention of Future Deaths': True, 'Mental Health related deaths': True, 'Railway related deaths': True, 'Suicide (from 2015)': True}
# ['South London and Maudsley NHS Foundation', ' Metropolitan Police service']
# {'title': 'Kerry Aldridge', 'published': '18 March 2020', 'timestamp': '2020-03-18T12:51:46+00:00', 'Prevention of Future Deaths': True, 'Mental Health related deaths': True, 'Railway related deaths': True, 'Suicide (from 2015)': True, 'dateofreport': '10 February 2020', 'ref': '2020-0055', 'deceasedname': 'Kerry Aldridge', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Railway related deaths; Suicide (from 2015); Mental Health related deaths', 'thisreportisbeingsentto': 'South London and Maudsley NHS Foundation; Metropolitan Police service', 'South London and Maudsley NHS Foundation': True, ' Metropolitan Police service': True}

# %% [markdown]
# We could have used an if/elif block like this...
#
# ```{python}
#     if "Date of report: " in t:
#       record['reportdate'] = t.replace("Date of report: ","")
#     elif "Ref: " in t:
#       record['ref'] = t.replace("Ref: ","")
#     elif "Deceased name: " in t:
#       record['deceasedname'] = t.replace("Deceased name: ","")
#     elif "Coroners name: " in t:
#       record['coronername'] = t.replace("Coroners name: ","")
#     elif "Coroners Area: " in t:
#       record['coronerarea'] = t.replace("Coroners Area: ","")
#     elif "This report is being sent to: " in t:
#       record['sentto'] = t.replace("This report is being sent to: ","")
# ```
#
# ...but the approach essentially does the same more elegantly

# %% [markdown]
# ### Grab the PDF links and titles
#
# Now to expand the function to fetch the PDFs.

# %%
#Create empty record to store data
record = {}

#define the function
def scrapedetail(detailurl):
  #store the url
  record['url'] = detailurl
  #scrape webpage into a variable called 'html'
  html = scraperwiki.scrape(detailurl)
  #convert from a string into an lxml object that can be parsed using lxml functions
  root = lxml.html.fromstring(html)
  #use the lxml function cssselect to grab anything inside an <article> tag, which is where the reports are
  articles = root.cssselect('article')
  #there's only one, so store that
  article = articles[0]
  #grab the <h1> tags with links
  h1s = article.cssselect('h1')
  #There should only be one, so we grab the text of that and store in the dictionary variable 'record'
  record['title'] = h1s[0].text_content()
  #grab the <time> tags
  times = article.cssselect('time')
  #there's only 1, grab the text content of that
  record['published'] = times[0].text_content()
  #grab the datetime= attribute, this is more specifically encoded
  record['timestamp'] = times[0].attrib['datetime']
  #print(record)
  #grab all the <span> tags
  spans = article.cssselect('span a')
  #Create an empty list to store the text
  spantext = []
  #loop through the spans and store the text in that list
  for span in spans:
    spantext.append(span.text_content())
  #Remove the two values we don't want
  spantext.remove('PFD Report')
  spantext.remove('Coroner')
  #Create a field for each category we find and store a True value against it
  for t in spantext:
    record[t] = True
  #print(record)
  #grab the <p> tags
  ps = article.cssselect('div.entry-content p')
  #Create an empty list to store the text content
  ptexts = []
  #Loop through the p tags and append the text to that list
  for p in ps:
    ptexts.append(p.text_content())
  #Loop through that list of paragraph text
  for t in ptexts:
    #Split into the label (e.g. Ref:) and the value (e.g. Andrew Harris) and store in a list
    tsplit = t.split(": ")
    #this line converts the text label to a key by removing spaces and making it lowercase
    record[tsplit[0].replace(" ","").lower()] = tsplit[1]
    #For one in particular we want to repeat the process of 
    # creating fields based on values and setting to True
    if "This report is being sent to: " in t:
      #Remove the label part and store the list of recipients
      recipients = t.replace("This report is being sent to: ","").split(";")
      #Use each as a key and store the True value against it
      for r in recipients:
        record[r] = True
  #the link to the PDF report is in <div class="download-box"> - grab all...
  pdfs = article.cssselect('li.pdf div a')
  #How many did we get
  #print(len(pdfs))
  #Store that
  record['num_of_pdfs'] = len(pdfs)
  #Some pages have no link to a report, so we need an if test before we try to extract that
  if len(pdfs)>0:
    pdflink = pdfs[0].attrib['href']
    #print(pdflink)
  else:
    pdflink = "NO REPORT LINK"
  record['pdflink'] = pdflink
  #Most pages have a response document, so here's another test
  if len(pdfs)>1:
    #Record how many responses there are
    record['responses'] = len(pdfs)-1
    #Loop through them - if there's more than one then we create different fields
    for i in range(1,len(pdfs)):
      #Create some field names by combining the index a string
      responseurlnum = "responseurl"+str(i)
      responsetitlenum = "responsetitle"+str(i)
      responseorgnum = "responseorg"+str(i)
      #Store attributes at that index under those field names
      record[responseurlnum] = pdfs[i].attrib['href']
      record[responsetitlenum] = pdfs[i].attrib['title']
      record[responseorgnum] = pdfs[i].attrib['title'].replace(" Response from ","").replace(record['ref'],"").replace(" Redacted","")
  #Return the data stored in 'record'
  return(record)
  

#Test the function, storing results in 'testresults'
testresults = scrapedetail("https://www.judiciary.uk/publications/kerry-aldridge/")
#Print
print(testresults)
# Out:
# {'url': 'https://www.judiciary.uk/publications/kerry-aldridge/', 'title': 'Kerry Aldridge', 'published': '18 March 2020', 'timestamp': '2020-03-18T12:51:46+00:00', 'Prevention of Future Deaths': True, 'Mental Health related deaths': True, 'Railway related deaths': True, 'Suicide (from 2015)': True, 'dateofreport': '10 February 2020', 'ref': '2020-0055', 'deceasedname': 'Kerry Aldridge', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Railway related deaths; Suicide (from 2015); Mental Health related deaths', 'thisreportisbeingsentto': 'South London and Maudsley NHS Foundation; Metropolitan Police service', 'South London and Maudsley NHS Foundation': True, ' Metropolitan Police service': True, 'num_of_pdfs': 2, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/03/Kerry-Aldridge-2020-0055-Redacted.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation'}

# %% [markdown]
# ## Scraping links from the results pages to run our scraper on
#
# Now that function is finished. We can return to the code that we wrote to scrape a category results page - and simplify it so it just grabs the link:

# %%
#create a function to scrape each results page
def scraperesultspage(url):
    #scrape webpage into a variable called 'html'
    html = scraperwiki.scrape(url)
    #convert from a string into an lxml object that can be parsed using lxml functions
    root = lxml.html.fromstring(html)
    #use the lxml function cssselect to grab anything inside an <article> tag, which is where the reports are
    detaillinks = root.cssselect('article h5 a')
    #That will be a list of lxml objects, so we need to create an empty list
    # to store the href attributes we extract from those
    detailurls = []
    #Now loop through the list of lxml objects
    for i in detaillinks:
      #Extract the href and append to that list
      detailurls.append(i.attrib['href'])
    #Return to whatever called this function
    return(detailurls)

#test it
testlist = scraperesultspage("https://www.judiciary.uk/publication-jurisdiction/coroner/")
print(testlist)
# Out:
# ['https://www.judiciary.uk/publications/linda-phillipson/', 'https://www.judiciary.uk/publications/peter-howarth/', 'https://www.judiciary.uk/publications/laura-parsons/', 'https://www.judiciary.uk/publications/ellie-isaacs/', 'https://www.judiciary.uk/publications/zoe-knight/', 'https://www.judiciary.uk/publications/carlington-spencer/', 'https://www.judiciary.uk/publications/daniel-coleman/', 'https://www.judiciary.uk/publications/dereck-john-chapman/', 'https://www.judiciary.uk/publications/toby-nieland/', 'https://www.judiciary.uk/publications/viktor-scott-brown/']

# %% [markdown]
# ### Generate a list of URLs to loop through
#
# This will work for the first page, but we need to run this on multiple pages.
#
# When we go to page 2 the URL changes to this:
#
# https://www.judiciary.uk/publication-jurisdiction/coroner/page/2/
#
# So we can start from:
#
# https://www.judiciary.uk/publication-jurisdiction/coroner/page/1
#
# And then add 1 to that number until we get to 332, the last page shown on the navigation.

# %%
#Store the URL without that number - the bit that never changes
baseurl = "https://www.judiciary.uk/publication-jurisdiction/coroner/page/"
#Generate a range of numbers from 1 to 322 (the last number shown is not included)
pagenums = range(1,323)
#Create an empty list to store our urls in
pageurls = []
#Loop through the page numbers and add them to the base url
for i in pagenums:
  #The str() function is used to convert the number to a string 
  #so it can be combined with the other string
  fullurl = baseurl+str(i)
  #Append to the previously empty list
  pageurls.append(fullurl)

#Check the length of the list
print(len(pageurls))
#Check the first and last urls
print(pageurls[0])
print(pageurls[-1])
# Out:
# 322
# https://www.judiciary.uk/publication-jurisdiction/coroner/page/1
# https://www.judiciary.uk/publication-jurisdiction/coroner/page/322

# %% [markdown]
# ## Loop through the URLs and apply the detail scraper function
#
# Now we test the two functions in two nested loops: one that loops through the list of results URLs we generated, and fetches the 10 detail URLs from each; then another loop which goes through those 10 detail URLs and scrapes the data.
#
# We limit the loops on the first run to just grab the first two items of each (2 results URLs, then 2 detail pages from each):

# %%
#Loop through those results urls
for i in pageurls[:2]:
  #On each one, scrape the links to the detail pages
  detailurls = scraperesultspage(i)
  #Loop through the list of links
  for i in detailurls[:2]:
    testresults = scrapedetail(i)
    #Print
    print(testresults)
# Out:
# {'url': 'https://www.judiciary.uk/publications/linda-phillipson/', 'title': 'Linda Phillipson', 'published': '10 November 2020', 'timestamp': '2020-11-10T16:08:08+00:00', 'Prevention of Future Deaths': True, 'Mental Health related deaths': True, 'Railway related deaths': True, 'Suicide (from 2015)': True, 'dateofreport': '8 September 2020', 'ref': '2020-0172', 'deceasedname': 'Linda Phillipson', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Hospital death (Clinical procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Western Sussex Hospital Trust', 'South London and Maudsley NHS Foundation': True, ' Metropolitan Police service': True, 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/11/Linda-Phillipson-2020-0172_Redacted.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation', 'Hospital Death (Clinical Procedures and medical management) related deaths': True, 'coronername': 'Veronica Hamilton-Deeley', 'coronerarea': 'Brighton and Hove', 'Western Sussex Hospital Trust': True}
# {'url': 'https://www.judiciary.uk/publications/peter-howarth/', 'title': 'Peter Howarth', 'published': '10 November 2020', 'timestamp': '2020-11-10T15:54:47+00:00', 'Prevention of Future Deaths': True, 'Mental Health related deaths': True, 'Railway related deaths': True, 'Suicide (from 2015)': True, 'dateofreport': '8 September 2020', 'ref': '2020-0171', 'deceasedname': 'Peter Howarth', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Care Home health related deaths; Hospital death (Clinical procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Borough Care', 'South London and Maudsley NHS Foundation': True, ' Metropolitan Police service': True, 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/11/Peter-Howarth-2020-0171_Redacted.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation', 'Hospital Death (Clinical Procedures and medical management) related deaths': True, 'coronername': 'Chris Morris', 'coronerarea': 'Greater Manchester South', 'Western Sussex Hospital Trust': True, 'Care Home Health related deaths': True, 'Borough Care': True}
# {'url': 'https://www.judiciary.uk/publications/malyun-karama/', 'title': 'Malyun Karama', 'published': '26 October 2020', 'timestamp': '2020-10-26T14:56:50+00:00', 'Prevention of Future Deaths': True, 'Mental Health related deaths': True, 'Railway related deaths': True, 'Suicide (from 2015)': True, 'dateofreport': '21 August 2020', 'ref': '2020-0162', 'deceasedname': 'Malyun Karama', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Hospital death (Clinical procedure and medical management) related deaths', 'thisreportisbeingsentto': 'Royal Free Hospital', 'South London and Maudsley NHS Foundation': True, ' Metropolitan Police service': True, 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/10/Malyun-Karama-2020-0162_Redacted.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation', 'Hospital Death (Clinical Procedures and medical management) related deaths': True, 'coronername': 'M E Hassell', 'coronerarea': 'Inner North London', 'Western Sussex Hospital Trust': True, 'Care Home Health related deaths': True, 'Borough Care': True, 'Royal Free Hospital': True}
# {'url': 'https://www.judiciary.uk/publications/ian-allen/', 'title': 'Ian Allen', 'published': '26 October 2020', 'timestamp': '2020-10-26T14:32:57+00:00', 'Prevention of Future Deaths': True, 'Mental Health related deaths': True, 'Railway related deaths': True, 'Suicide (from 2015)': True, 'dateofreport': '17 August 2020', 'ref': '2020-0161', 'deceasedname': 'Ian Allen', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Care Home health deaths; Alcohol, drug and medication related deaths', 'thisreportisbeingsentto': 'Birmingham and Solihull Mental Health Foundation Trust; Department for Health and Social Care', 'South London and Maudsley NHS Foundation': True, ' Metropolitan Police service': True, 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/10/Ian-Allen-2020-0161.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation', 'Hospital Death (Clinical Procedures and medical management) related deaths': True, 'coronername': 'Louise Hunt', 'coronerarea': 'Birmingham and Solihull', 'Western Sussex Hospital Trust': True, 'Care Home Health related deaths': True, 'Borough Care': True, 'Royal Free Hospital': True, 'Alcohol, drug and medication related deaths': True, 'Birmingham and Solihull Mental Health Foundation Trust': True, ' Department for Health and Social Care': True}

# %% [markdown]
# ## Storing the results in a datastore
#
# Now let's see how easily we can deal with the resulting dictionaries. These will be of varying lengths so we try using the `sql.save()` function from the scraperwiki library first.

# %%
#Loop through those results urls
for i in pageurls[:2]:
  #On each one, scrape the links to the detail pages
  detailurls = scraperesultspage(i)
  #Loop through the list of links
  for i in detailurls[:2]:
    testresults = scrapedetail(i)
    #Print
    print(testresults)
    scraperwiki.sql.save(['url'], testresults, table_name = "testrun")
# Out:
# {'url': 'https://www.judiciary.uk/publications/linda-phillipson/', 'title': 'Linda Phillipson', 'published': '10 November 2020', 'timestamp': '2020-11-10T16:08:08+00:00', 'Prevention of Future Deaths': True, 'Mental Health related deaths': True, 'Railway related deaths': True, 'Suicide (from 2015)': True, 'dateofreport': '8 September 2020', 'ref': '2020-0172', 'deceasedname': 'Linda Phillipson', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Hospital death (Clinical procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Western Sussex Hospital Trust', 'South London and Maudsley NHS Foundation': True, ' Metropolitan Police service': True, 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/11/Linda-Phillipson-2020-0172_Redacted.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation', 'Hospital Death (Clinical Procedures and medical management) related deaths': True, 'coronername': 'Veronica Hamilton-Deeley', 'coronerarea': 'Brighton and Hove', 'Western Sussex Hospital Trust': True, 'Care Home Health related deaths': True, 'Borough Care': True, 'Royal Free Hospital': True, 'Alcohol, drug and medication related deaths': True, 'Birmingham and Solihull Mental Health Foundation Trust': True, ' Department for Health and Social Care': True}
# {'url': 'https://www.judiciary.uk/publications/peter-howarth/', 'title': 'Peter Howarth', 'published': '10 November 2020', 'timestamp': '2020-11-10T15:54:47+00:00', 'Prevention of Future Deaths': True, 'Mental Health related deaths': True, 'Railway related deaths': True, 'Suicide (from 2015)': True, 'dateofreport': '8 September 2020', 'ref': '2020-0171', 'deceasedname': 'Peter Howarth', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Care Home health related deaths; Hospital death (Clinical procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Borough Care', 'South London and Maudsley NHS Foundation': True, ' Metropolitan Police service': True, 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/11/Peter-Howarth-2020-0171_Redacted.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation', 'Hospital Death (Clinical Procedures and medical management) related deaths': True, 'coronername': 'Chris Morris', 'coronerarea': 'Greater Manchester South', 'Western Sussex Hospital Trust': True, 'Care Home Health related deaths': True, 'Borough Care': True, 'Royal Free Hospital': True, 'Alcohol, drug and medication related deaths': True, 'Birmingham and Solihull Mental Health Foundation Trust': True, ' Department for Health and Social Care': True}
# {'url': 'https://www.judiciary.uk/publications/malyun-karama/', 'title': 'Malyun Karama', 'published': '26 October 2020', 'timestamp': '2020-10-26T14:56:50+00:00', 'Prevention of Future Deaths': True, 'Mental Health related deaths': True, 'Railway related deaths': True, 'Suicide (from 2015)': True, 'dateofreport': '21 August 2020', 'ref': '2020-0162', 'deceasedname': 'Malyun Karama', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Hospital death (Clinical procedure and medical management) related deaths', 'thisreportisbeingsentto': 'Royal Free Hospital', 'South London and Maudsley NHS Foundation': True, ' Metropolitan Police service': True, 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/10/Malyun-Karama-2020-0162_Redacted.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation', 'Hospital Death (Clinical Procedures and medical management) related deaths': True, 'coronername': 'M E Hassell', 'coronerarea': 'Inner North London', 'Western Sussex Hospital Trust': True, 'Care Home Health related deaths': True, 'Borough Care': True, 'Royal Free Hospital': True, 'Alcohol, drug and medication related deaths': True, 'Birmingham and Solihull Mental Health Foundation Trust': True, ' Department for Health and Social Care': True}
# {'url': 'https://www.judiciary.uk/publications/ian-allen/', 'title': 'Ian Allen', 'published': '26 October 2020', 'timestamp': '2020-10-26T14:32:57+00:00', 'Prevention of Future Deaths': True, 'Mental Health related deaths': True, 'Railway related deaths': True, 'Suicide (from 2015)': True, 'dateofreport': '17 August 2020', 'ref': '2020-0161', 'deceasedname': 'Ian Allen', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Care Home health deaths; Alcohol, drug and medication related deaths', 'thisreportisbeingsentto': 'Birmingham and Solihull Mental Health Foundation Trust; Department for Health and Social Care', 'South London and Maudsley NHS Foundation': True, ' Metropolitan Police service': True, 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/10/Ian-Allen-2020-0161.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation', 'Hospital Death (Clinical Procedures and medical management) related deaths': True, 'coronername': 'Louise Hunt', 'coronerarea': 'Birmingham and Solihull', 'Western Sussex Hospital Trust': True, 'Care Home Health related deaths': True, 'Borough Care': True, 'Royal Free Hospital': True, 'Alcohol, drug and medication related deaths': True, 'Birmingham and Solihull Mental Health Foundation Trust': True, ' Department for Health and Social Care': True}

# %%
print(scraperwiki.sql.select("* from testrun"))
# Out:
# [{'url': 'https://www.judiciary.uk/publications/linda-phillipson/', 'title': 'Linda Phillipson', 'published': '10 November 2020', 'timestamp': '2020-11-10T16:08:08+00:00', 'Prevention of Future Deaths': 1, 'Mental Health related deaths': 1, 'Railway related deaths': 1, 'Suicide (from 2015)': 1, 'dateofreport': '8 September 2020', 'ref': '2020-0172', 'deceasedname': 'Linda Phillipson', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Hospital death (Clinical procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Western Sussex Hospital Trust', 'South London and Maudsley NHS Foundation': 1, ' Metropolitan Police service': 1, 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/11/Linda-Phillipson-2020-0172_Redacted.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation', 'Hospital Death (Clinical Procedures and medical management) related deaths': 1, 'coronername': 'Veronica Hamilton-Deeley', 'coronerarea': 'Brighton and Hove', 'Western Sussex Hospital Trust': 1, 'Care Home Health related deaths': 1, 'Borough Care': 1, 'Royal Free Hospital': 1, 'Alcohol, drug and medication related deaths': 1, 'Birmingham and Solihull Mental Health Foundation Trust': 1, ' Department for Health and Social Care': 1}, {'url': 'https://www.judiciary.uk/publications/peter-howarth/', 'title': 'Peter Howarth', 'published': '10 November 2020', 'timestamp': '2020-11-10T15:54:47+00:00', 'Prevention of Future Deaths': 1, 'Mental Health related deaths': 1, 'Railway related deaths': 1, 'Suicide (from 2015)': 1, 'dateofreport': '8 September 2020', 'ref': '2020-0171', 'deceasedname': 'Peter Howarth', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Care Home health related deaths; Hospital death (Clinical procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Borough Care', 'South London and Maudsley NHS Foundation': 1, ' Metropolitan Police service': 1, 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/11/Peter-Howarth-2020-0171_Redacted.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation', 'Hospital Death (Clinical Procedures and medical management) related deaths': 1, 'coronername': 'Chris Morris', 'coronerarea': 'Greater Manchester South', 'Western Sussex Hospital Trust': 1, 'Care Home Health related deaths': 1, 'Borough Care': 1, 'Royal Free Hospital': 1, 'Alcohol, drug and medication related deaths': 1, 'Birmingham and Solihull Mental Health Foundation Trust': 1, ' Department for Health and Social Care': 1}, {'url': 'https://www.judiciary.uk/publications/malyun-karama/', 'title': 'Malyun Karama', 'published': '26 October 2020', 'timestamp': '2020-10-26T14:56:50+00:00', 'Prevention of Future Deaths': 1, 'Mental Health related deaths': 1, 'Railway related deaths': 1, 'Suicide (from 2015)': 1, 'dateofreport': '21 August 2020', 'ref': '2020-0162', 'deceasedname': 'Malyun Karama', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Hospital death (Clinical procedure and medical management) related deaths', 'thisreportisbeingsentto': 'Royal Free Hospital', 'South London and Maudsley NHS Foundation': 1, ' Metropolitan Police service': 1, 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/10/Malyun-Karama-2020-0162_Redacted.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/upl ...

# %% [markdown]
# Here's that data organised in a way that's easier to read:
#
# ```
# [
#   {'url': 'https://www.judiciary.uk/publications/linda-phillipson/', 'title': 'Linda Phillipson', 'published': '10 November 2020', 'timestamp': '2020-11-10T16:08:08+00:00', 'Prevention of Future Deaths': 1, 'Mental Health related deaths': 1, 'Railway related deaths': 1, 'Suicide (from 2015)': 1, 'dateofreport': '8 September 2020', 'ref': '2020-0172', 'deceasedname': 'Linda Phillipson', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Hospital death (Clinical procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Western Sussex Hospital Trust', 'South London and Maudsley NHS Foundation': 1, ' Metropolitan Police service': 1, 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/11/Linda-Phillipson-2020-0172_Redacted.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation', 'Hospital Death (Clinical Procedures and medical management) related deaths': 1, 'coronername': 'Veronica Hamilton-Deeley', 'coronerarea': 'Brighton and Hove', 'Western Sussex Hospital Trust': 1, 'Care Home Health related deaths': 1, 'Borough Care': 1, 'Royal Free Hospital': 1, 'Alcohol, drug and medication related deaths': 1, 'Birmingham and Solihull Mental Health Foundation Trust': 1, ' Department for Health and Social Care': 1},
#   {'url': 'https://www.judiciary.uk/publications/peter-howarth/', 'title': 'Peter Howarth', 'published': '10 November 2020', 'timestamp': '2020-11-10T15:54:47+00:00', 'Prevention of Future Deaths': 1, 'Mental Health related deaths': 1, 'Railway related deaths': 1, 'Suicide (from 2015)': 1, 'dateofreport': '8 September 2020', 'ref': '2020-0171', 'deceasedname': 'Peter Howarth', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Care Home health related deaths; Hospital death (Clinical procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Borough Care', 'South London and Maudsley NHS Foundation': 1, ' Metropolitan Police service': 1, 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/11/Peter-Howarth-2020-0171_Redacted.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation', 'Hospital Death (Clinical Procedures and medical management) related deaths': 1, 'coronername': 'Chris Morris', 'coronerarea': 'Greater Manchester South', 'Western Sussex Hospital Trust': 1, 'Care Home Health related deaths': 1, 'Borough Care': 1, 'Royal Free Hospital': 1, 'Alcohol, drug and medication related deaths': 1, 'Birmingham and Solihull Mental Health Foundation Trust': 1, ' Department for Health and Social Care': 1},
#   {'url': 'https://www.judiciary.uk/publications/malyun-karama/', 'title': 'Malyun Karama', 'published': '26 October 2020', 'timestamp': '2020-10-26T14:56:50+00:00', 'Prevention of Future Deaths': 1, 'Mental Health related deaths': 1, 'Railway related deaths': 1, 'Suicide (from 2015)': 1, 'dateofreport': '21 August 2020', 'ref': '2020-0162', 'deceasedname': 'Malyun Karama', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Hospital death (Clinical procedure and medical management) related deaths', 'thisreportisbeingsentto': 'Royal Free Hospital', 'South London and Maudsley NHS Foundation': 1, ' Metropolitan Police service': 1, 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/10/Malyun-Karama-2020-0162_Redacted.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation', 'Hospital Death (Clinical Procedures and medical management) related deaths': 1, 'coronername': 'M E Hassell', 'coronerarea': 'Inner North London', 'Western Sussex Hospital Trust': 1, 'Care Home Health related deaths': 1, 'Borough Care': 1, 'Royal Free Hospital': 1, 'Alcohol, drug and medication related deaths': 1, 'Birmingham and Solihull Mental Health Foundation Trust': 1, ' Department for Health and Social Care': 1},
#   {'url': 'https://www.judiciary.uk/publications/ian-allen/', 'title': 'Ian Allen', 'published': '26 October 2020', 'timestamp': '2020-10-26T14:32:57+00:00', 'Prevention of Future Deaths': 1, 'Mental Health related deaths': 1, 'Railway related deaths': 1, 'Suicide (from 2015)': 1, 'dateofreport': '17 August 2020', 'ref': '2020-0161', 'deceasedname': 'Ian Allen', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Care Home health deaths; Alcohol, drug and medication related deaths', 'thisreportisbeingsentto': 'Birmingham and Solihull Mental Health Foundation Trust; Department for Health and Social Care', 'South London and Maudsley NHS Foundation': 1, ' Metropolitan Police service': 1, 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/10/Ian-Allen-2020-0161.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation', 'Hospital Death (Clinical Procedures and medical management) related deaths': 1, 'coronername': 'Louise Hunt', 'coronerarea': 'Birmingham and Solihull', 'Western Sussex Hospital Trust': 1, 'Care Home Health related deaths': 1, 'Borough Care': 1, 'Royal Free Hospital': 1, 'Alcohol, drug and medication related deaths': 1, 'Birmingham and Solihull Mental Health Foundation Trust': 1, ' Department for Health and Social Care': 1}
#   ]
# ```

# %% [markdown]
# This part in the first entry is where we have a problem:
#
# `'Prevention of Future Deaths': 1, 'Mental Health related deaths': 1,`
#
# That doesn't match the [entry on the page](https://www.judiciary.uk/publications/linda-phillipson/) which only sits in one category.
#
# The same problem applies to organisations:
#
# `'thisreportisbeingsentto': 'Western Sussex Hospital Trust', 'South London and Maudsley NHS Foundation': 1, ' Metropolitan Police service': 1,`

# %% [markdown]
# ## Using pandas
#
# We might try a different approach. [This Stackoverflow entry on *Creating dataframe from a dictionary where entries have different lengths*](https://stackoverflow.com/questions/19736080/creating-dataframe-from-a-dictionary-where-entries-have-different-lengths) outlines a possible solution with `pandas`.

# %%
#import the pandas library
import pandas as pd
import numpy as np

# %% [markdown]
# Let's try out some of the code at that page and see what we can do with it:

# %%
d = dict( A = np.array([1,2]), B = np.array([1,2,3,4]) )

print(d)

pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in d.items() ]))
# Out:
# {'A': array([1, 2]), 'B': array([1, 2, 3, 4])}
#      A  B
# 0  1.0  1
# 1  2.0  2
# 2  NaN  3
# 3  NaN  4

# %% [markdown]
# The difference here is that there is only **one** dict, with each key representing a column, and the value attached to that key being an **array** of all the values in that column.
#
# This won't work for us because even if we created a list as soon as a new category/tag was encountered, the lists wouldn't match up properly to ensure that as *rows* the data would all belong to the same page.

# %% [markdown]
# ## Adjusting the function to start with all categories
#
# Our solution, then, would be to update the function to begin with *all* categories rather than taking them from the data itself (an option we identified earlier).
#
# In the function we had these lines of code that fetched categories from the HTML itself:
#
# ```
# #Create a field for each category we find and store a True value against it
#   for t in spantext:
#     record[t] = True
# ```
#
# We need to replace that with:
# 1. a set of keys for *all* the possible categories, set to `False` by default
# 2. some lines that turn *some* of those to `True` if they are found in the HTML.
#
# Let's create that set of category keys. We can do this by repeating some code we used earlier to scrape the category links, with a small tweak to print the text of the links rather than the value of the href attribute:

# %%
#store the URL we want to start scraping from
starturl = 'https://www.judiciary.uk/related-offices-and-bodies/office-chief-coroner/https-www-judiciary-uk-subject-community-health-care-and-emergency-services-related-deaths/'
html = scraperwiki.scrape(starturl)
#convert from a string into an lxml object that can be parsed using lxml functions
root = lxml.html.fromstring(html)
#use the lxml function cssselect to grab any link inside a list inside an <article> tag, which is where the category linksare
catlinks = root.cssselect('article ul li a')
#measure the length of that list of matches, and print it
print ('found ',len(catlinks), ' reports')
#Loop through the matches and print the href="" attribute
for link in catlinks:
  print(link.text_content())
# Out:
# found  16  reports
# Accident at Work and Health and Safety related deaths
# Alcohol, drug and medication related deaths
# Care Home Health related deaths
# Child Death
# Community health care and Emergency Services related deaths
# Emergency services related deaths (2019 onwards)
# Hospital Death (Clinical Procedures and medical management) related deaths
# Mental Health related deaths
# Other related deaths
# Police related deaths
# Product related deaths
# Road (Highways Safety) related deaths
# Railway related deaths
# State Custody related deaths
# Suicide
# Wales prevention of future deaths reports (2019 onwards)

# %% [markdown]
# A couple of these include "(2019 onwards)" so we need to check if the categories are referred to in the same way in the relevant reports.
#
# Looking at the reports on https://www.judiciary.uk/subject/emergency-services-related-deaths-prevention-of-future-deaths/ it does indeed seem that they do.

# %% [markdown]
# ### Seed the dictionary with categories set to False
#
# Now we can use that list to seed the dictionary.

# %%
record = {}
for link in catlinks:
  record[link.text_content()] = False
print(record)
# Out:
# {'Accident at Work and Health and Safety related deaths': False, 'Alcohol, drug and medication related deaths': False, 'Care Home Health related deaths': False, 'Child Death': False, 'Community health care and Emergency Services related deaths': False, 'Emergency services related deaths (2019 onwards)': False, 'Hospital Death (Clinical Procedures and medical management) related deaths': False, 'Mental Health related deaths': False, 'Other related deaths': False, 'Police related deaths': False, 'Product related deaths': False, 'Road (Highways Safety) related deaths': False, 'Railway related deaths': False, 'State Custody related deaths': False, 'Suicide': False, 'Wales prevention of future deaths reports (2019 onwards)': False}

# %% [markdown]
# With those defaults set, the function now just *changes* them where a match is found:
#
# ```
#   #Create a field for each category we find and store a True value against it
#   for t in spantext:
#     record[t] = True
# ```
#
# We also remove the similar code for recipients:
#
# ```
# for r in recipients:
#   record[r] = True
# ```
#
# and just add each new recipient to a list (that might be used later) instead, by first creating that list with `recipientlist = []` then in the function changing the loop to:
#
# ```
# for r in recipients:
#   recipientlist.append(r)
# ```
#
# Later we can use `set(recipientlist)` to convert the list to a set of unique entries - but the list will allow us to count frequency.

# %%
#Create an empty list for recipients
recipientlist = []

#define the function
def scrapedetail(detailurl):
  #store the url
  record['url'] = detailurl
  #scrape webpage into a variable called 'html'
  html = scraperwiki.scrape(detailurl)
  #convert from a string into an lxml object that can be parsed using lxml functions
  root = lxml.html.fromstring(html)
  #use the lxml function cssselect to grab anything inside an <article> tag, which is where the reports are
  articles = root.cssselect('article')
  #there's only one, so store that
  article = articles[0]
  #grab the <h1> tags with links
  h1s = article.cssselect('h1')
  #There should only be one, so we grab the text of that and store in the dictionary variable 'record'
  record['title'] = h1s[0].text_content()
  #grab the <time> tags
  times = article.cssselect('time')
  #there's only 1, grab the text content of that
  record['published'] = times[0].text_content()
  #grab the datetime= attribute, this is more specifically encoded
  record['timestamp'] = times[0].attrib['datetime']
  #grab all the <span> tags
  spans = article.cssselect('span a')
  #Create an empty list to store the text
  spantext = []
  #loop through the spans and store the text in that list
  for span in spans:
    spantext.append(span.text_content())
  #Remove the two values we don't want
  spantext.remove('PFD Report')
  spantext.remove('Coroner')
  #Create a field for each category we find and change the default False value to a True value
  for t in spantext:
    record[t] = True
  #grab the <p> tags
  ps = article.cssselect('div.entry-content p')
  #Create an empty list to store the text content
  ptexts = []
  #Loop through the p tags and append the text to that list
  for p in ps:
    ptexts.append(p.text_content())
  #Loop through that list of paragraph text
  for t in ptexts:
    #Split into the label (e.g. Ref:) and the value (e.g. Andrew Harris) and store in a list
    tsplit = t.split(": ")
    #this line converts the text label to a key by removing spaces and making it lowercase
    record[tsplit[0].replace(" ","").lower()] = tsplit[1]
    #For one in particular we want to repeat the process of 
    # creating fields based on values and setting to True
    if "This report is being sent to: " in t:
      #Remove the label part and store the list of recipients
      recipients = t.replace("This report is being sent to: ","").split(";")
      #Add to the ongoing list of recipients
      for r in recipients:
        recipientlist.append(r)
  #the link to the PDF report is in <div class="download-box"> - grab all...
  pdfs = article.cssselect('li.pdf div a')
  #How many did we get
  #print(len(pdfs))
  #Store that
  record['num_of_pdfs'] = len(pdfs)
  #Some pages have no link to a report, so we need an if test before we try to extract that
  if len(pdfs)>0:
    pdflink = pdfs[0].attrib['href']
    #print(pdflink)
  else:
    pdflink = "NO REPORT LINK"
  record['pdflink'] = pdflink
  #Most pages have a response document, so here's another test
  if len(pdfs)>1:
    #Record how many responses there are
    record['responses'] = len(pdfs)-1
    #Loop through them - if there's more than one then we create different fields
    for i in range(1,len(pdfs)):
      #Create some field names by combining the index a string
      responseurlnum = "responseurl"+str(i)
      responsetitlenum = "responsetitle"+str(i)
      responseorgnum = "responseorg"+str(i)
      #Store attributes at that index under those field names
      record[responseurlnum] = pdfs[i].attrib['href']
      record[responsetitlenum] = pdfs[i].attrib['title']
      record[responseorgnum] = pdfs[i].attrib['title'].replace(" Response from ","").replace(record['ref'],"").replace(" Redacted","")
  #Return the data stored in 'record'
  return(record)

# %%
#Test the function, storing results in 'testresults'
testresults = scrapedetail("https://www.judiciary.uk/publications/kerry-aldridge/")
#Print
print(testresults)
# Out:
# {'Accident at Work and Health and Safety related deaths': False, 'Alcohol, drug and medication related deaths': False, 'Care Home Health related deaths': False, 'Child Death': False, 'Community health care and Emergency Services related deaths': False, 'Emergency services related deaths (2019 onwards)': False, 'Hospital Death (Clinical Procedures and medical management) related deaths': False, 'Mental Health related deaths': True, 'Other related deaths': False, 'Police related deaths': False, 'Product related deaths': False, 'Road (Highways Safety) related deaths': False, 'Railway related deaths': True, 'State Custody related deaths': False, 'Suicide': False, 'Wales prevention of future deaths reports (2019 onwards)': False, 'url': 'https://www.judiciary.uk/publications/kerry-aldridge/', 'title': 'Kerry Aldridge', 'published': '18 March 2020', 'timestamp': '2020-03-18T12:51:46+00:00', 'Prevention of Future Deaths': True, 'Suicide (from 2015)': True, 'dateofreport': '10 February 2020', 'ref': '2020-0055', 'deceasedname': 'Kerry Aldridge', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Railway related deaths; Suicide (from 2015); Mental Health related deaths', 'thisreportisbeingsentto': 'South London and Maudsley NHS Foundation; Metropolitan Police service', 'num_of_pdfs': 2, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/03/Kerry-Aldridge-2020-0055-Redacted.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation'}

# %% [markdown]
# Checking this we can see that one category - Suicide - isn't stored as `True`. This is because the page itself says "Suicide (from 2015)".
#
# We can fix these mismatches manually - but a simpler option is to match on the URLs instead.

# %%
#store the URL we want to start scraping from
starturl = 'https://www.judiciary.uk/related-offices-and-bodies/office-chief-coroner/https-www-judiciary-uk-subject-community-health-care-and-emergency-services-related-deaths/'
html = scraperwiki.scrape(starturl)
#convert from a string into an lxml object that can be parsed using lxml functions
root = lxml.html.fromstring(html)
#use the lxml function cssselect to grab any link inside a list inside an <article> tag, which is where the category linksare
catlinks = root.cssselect('article ul li a')
#measure the length of that list of matches, and print it
print ('found ',len(catlinks), ' reports')
#Create an empty list to store
categoryurls = []
#Loop through the matches and print the href="" attribute
for link in catlinks:
  caturl = link.attrib['href']
  #print(caturl)
  categoryurls.append(link.attrib['href'])

print(categoryurls)
# Out:
# found  16  reports
# ['https://www.judiciary.uk/subject/accident-at-work-and-health-and-safety-related-deaths/', 'https://www.judiciary.uk/subject/alcohol-drug-and-medication-related-deaths/', 'https://www.judiciary.uk/subject/care-home-health-related-deaths/', 'https://www.judiciary.uk/subject/child-death', 'https://www.judiciary.uk/subject/community-health-care-and-emergency-services-related-deaths/', 'https://www.judiciary.uk/subject/emergency-services-related-deaths-prevention-of-future-deaths/', 'https://www.judiciary.uk/subject/hospital-death-clinical-procedures-and-medical-management-related-deaths/', 'https://www.judiciary.uk/subject/mental-health-related-deaths/', 'https://www.judiciary.uk/subject/other-related-deaths/', 'https://www.judiciary.uk/subject/police-related-deaths/', 'https://www.judiciary.uk/subject/product-related-deaths/', 'https://www.judiciary.uk/subject/road-highways-safety-related-deaths/', 'https://www.judiciary.uk/subject/railway-related-deaths/', 'https://www.judiciary.uk/subject/state-custody-related-deaths/', 'https://www.judiciary.uk/subject/suicide/', 'https://www.judiciary.uk/subject/wales-pfd-reports-related-deaths/']

# %% [markdown]
# This is the code we now need to change in the function:
#
# ```
# #Create an empty list to store the text
#   spantext = []
#   #loop through the spans and store the text in that list
#   for span in spans:
#     spantext.append(span.text_content())
#   #Remove the two values we don't want
#   spantext.remove('PFD Report')
#   spantext.remove('Coroner')
#   #Create a field for each category we find and change the default False value to a True value
#   for t in spantext:
#     record[t] = True
# ```
#
# Instead of storing text we are going to store URLs:
#
# ```
# #Create an empty list to store the links
#   spanhrefs = []
#   #loop through the spans and store the links in that list
#   for span in spans:
#     spanhrefs.append(span.attrib['href'])
#   #Remove the two values we don't want
#   spanhrefs.remove('https://www.judiciary.uk/publication-type/pfd-report/')
#   spanhrefs.remove('https://www.judiciary.uk/publication-jurisdiction/coroner/')
#   #Create a field for each category we find and change the default False value to a True value
#   for t in spanhrefs:
#     record[t] = True
# ```

# %% [markdown]
# We also need to change that default dictionary. Along the way, those URLs could be cleaned up so we don't have the redundant base part.

# %%
record = {}
for link in categoryurls:
  #This replaces the base URL and stops short of the / at the end of the URL
  record[link.replace("https://www.judiciary.uk/subject/","")[:-1]] = False
print(record)
# Out:
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': False, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': False, 'mental-health-related-deaths': False, 'other-related-deaths': False, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': False, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False}

# %% [markdown]
# And we need to update our code to replicate that cleaning too, so it still matches up:
#
# ```
# #Create an empty list to store the links
#   spanhrefs = []
#   #loop through the spans and store the links in that list
#   for span in spans:
#     spanhrefs.append(span.attrib['href'])
#   #Remove the two values we don't want
#   spanhrefs.remove('https://www.judiciary.uk/publication-type/pfd-report/')
#   spanhrefs.remove('https://www.judiciary.uk/publication-jurisdiction/coroner/')
#   #Create a field for each category we find and change the default False value to a True value
#   for t in spanhrefs:
#     record[t.replace("https://www.judiciary.uk/subject/","")[:-1]] = True
# ```

# %%
#Create that seeded dictionary
record = {}
for link in categoryurls:
  #This replaces the base URL and stops short of the / at the end of the URL
  record[link.replace("https://www.judiciary.uk/subject/","")[:-1]] = False
print(record)

#Create an empty list for recipients
recipientlist = []

#define the function
def scrapedetail(detailurl):
  #store the url
  record['url'] = detailurl
  #scrape webpage into a variable called 'html'
  html = scraperwiki.scrape(detailurl)
  #convert from a string into an lxml object that can be parsed using lxml functions
  root = lxml.html.fromstring(html)
  #use the lxml function cssselect to grab anything inside an <article> tag, which is where the reports are
  articles = root.cssselect('article')
  #there's only one, so store that
  #around 2135 reports in, there's a page that doesn't have one, so we add an if
  if len(articles) > 0:
    article = articles[0]
    #grab the <h1> tags with links
    h1s = article.cssselect('h1')
    #There should only be one, so we grab the text of that and store in the dictionary variable 'record'
    record['title'] = h1s[0].text_content()
    #grab the <time> tags
    times = article.cssselect('time')
    #there's only 1, grab the text content of that
    record['published'] = times[0].text_content()
    #grab the datetime= attribute, this is more specifically encoded
    record['timestamp'] = times[0].attrib['datetime']
    #grab all the <span> tags
    spans = article.cssselect('span a')
    #Create an empty list to store the links
    spanhrefs = []
    #loop through the spans and store the links in that list
    for span in spans:
      spanhrefs.append(span.attrib['href'])
    #Remove the two values we don't want
    #if these aren't there this returns list.remove(x): x not in list
    #So we nest in an if:
    if 'https://www.judiciary.uk/publication-type/pfd-report/' in spanhrefs:
      spanhrefs.remove('https://www.judiciary.uk/publication-type/pfd-report/')
    if 'https://www.judiciary.uk/publication-jurisdiction/coroner/' in spanhrefs:
      spanhrefs.remove('https://www.judiciary.uk/publication-jurisdiction/coroner/')
    #Create a field for each category we find and change the default False value to a True value
    for t in spanhrefs:
      #Strip out the base URL and stop before the / so it matches the keys
      record[t.replace("https://www.judiciary.uk/subject/","")[:-1]] = True
    #grab the <p> tags
    ps = article.cssselect('div.entry-content p')
    #Create an empty list to store the text content
    ptexts = []
    #Loop through the p tags and append the text to that list
    for p in ps:
      ptexts.append(p.text_content())
    #Loop through that list of paragraph text
    for t in ptexts:
      #Split into the label (e.g. Ref:) and the value (e.g. Andrew Harris) and store in a list
      tsplit = t.split(": ")
      #We need an if test here because some pages don't have this
      if len(tsplit) > 1:
        #this line converts the text label to a key by removing spaces and making it lowercase
        record[tsplit[0].replace(" ","").lower()] = tsplit[1]
      #And an else to specify there is no ref, otherwise the line later that uses this will break
      else:
        record['ref'] = "noref"
      #For one in particular we want to repeat the process of 
      # creating fields based on values and setting to True
      if "This report is being sent to: " in t:
        #Remove the label part and store the list of recipients
        recipients = t.replace("This report is being sent to: ","").split(";")
        #Add to the ongoing list of recipients
        for r in recipients:
          recipientlist.append(r)
    #the link to the PDF report is in <div class="download-box"> - grab all...
    pdfs = article.cssselect('li.pdf div a')
    #How many did we get
    #print(len(pdfs))
    #Store that
    record['num_of_pdfs'] = len(pdfs)
    #Some pages have no link to a report, so we need an if test before we try to extract that
    if len(pdfs)>0:
      pdflink = pdfs[0].attrib['href']
      #print(pdflink)
    else:
      pdflink = "NO REPORT LINK"
    record['pdflink'] = pdflink
    #Most pages have a response document, so here's another test
    if len(pdfs)>1:
      #Record how many responses there are
      record['responses'] = len(pdfs)-1
      #Loop through them - if there's more than one then we create different fields
      for i in range(1,len(pdfs)):
        #Create some field names by combining the index a string
        responseurlnum = "responseurl"+str(i)
        responsetitlenum = "responsetitle"+str(i)
        responseorgnum = "responseorg"+str(i)
        #Store attributes at that index under those field names
        record[responseurlnum] = pdfs[i].attrib['href']
        record[responsetitlenum] = pdfs[i].attrib['title']
        record[responseorgnum] = pdfs[i].attrib['title'].replace(" Response from ","").replace(record['ref'],"").replace(" Redacted","")
  #Return the data stored in 'record'
  return(record)
# Out:
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': False, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': False, 'mental-health-related-deaths': False, 'other-related-deaths': False, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': False, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False}

# %% [markdown]
# Then test again:

# %%
#Test the function, storing results in 'testresults'
testresults = scrapedetail("https://www.judiciary.uk/publications/kerry-aldridge/")
#Print
print(testresults)
# Out:
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': False, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': False, 'mental-health-related-deaths': True, 'other-related-deaths': False, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': False, 'railway-related-deaths': True, 'state-custody-related-deaths': False, 'suicide': True, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/kerry-aldridge/', 'title': 'Kerry Aldridge', 'published': '18 March 2020', 'timestamp': '2020-03-18T12:51:46+00:00', 'training-and-support': True, 'https://www.judiciary.uk/publication-type/guidance': True, 'https://www.judiciary.uk/publication-jurisdiction/tribunals': True, 'https://www.judiciary.uk/publication-jurisdiction/family-2': True, 'https://www.judiciary.uk/publication-jurisdiction/crime': True, 'https://www.judiciary.uk/publication-jurisdiction/civil': True, 'num_of_pdfs': 2, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/03/Kerry-Aldridge-2020-0055-Redacted.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'prevention-of-future-deaths': True, 'dateofreport': '10 February 2020', 'ref': '2020-0055', 'deceasedname': 'Kerry Aldridge', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Railway related deaths; Suicide (from 2015); Mental Health related deaths', 'thisreportisbeingsentto': 'South London and Maudsley NHS Foundation; Metropolitan Police service', 'responseorg1': 'South London and Maudsley NHS Foundation'}

# %% [markdown]
# This seems to match up to what we see.
#
# Now to test on a few pages:

# %%
#Loop through those results urls
for i in pageurls[:2]:
  #On each one, scrape the links to the detail pages
  detailurls = scraperesultspage(i)
  #Loop through the list of links
  for i in detailurls[:2]:
    testresults = scrapedetail(i)
    #Print
    print(testresults)
    scraperwiki.sql.save(['url'], testresults, table_name = "testrun2")
# Out:
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': True, 'care-home-health-related-deaths': True, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': True, 'other-related-deaths': False, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': False, 'railway-related-deaths': True, 'state-custody-related-deaths': False, 'suicide': True, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/linda-phillipson/', 'title': 'Linda Phillipson', 'published': '10 November 2020', 'timestamp': '2020-11-10T16:08:08+00:00', 'prevention-of-future-deaths': True, 'dateofreport': '8 September 2020', 'ref': '2020-0172', 'deceasedname': 'Linda Phillipson', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Hospital death (Clinical procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Western Sussex Hospital Trust', 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/11/Linda-Phillipson-2020-0172_Redacted.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation', 'coronername': 'Veronica Hamilton-Deeley', 'coronerarea': 'Brighton and Hove'}
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': True, 'care-home-health-related-deaths': True, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': True, 'other-related-deaths': False, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': False, 'railway-related-deaths': True, 'state-custody-related-deaths': False, 'suicide': True, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/peter-howarth/', 'title': 'Peter Howarth', 'published': '10 November 2020', 'timestamp': '2020-11-10T15:54:47+00:00', 'prevention-of-future-deaths': True, 'dateofreport': '8 September 2020', 'ref': '2020-0171', 'deceasedname': 'Peter Howarth', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Care Home health related deaths; Hospital death (Clinical procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Borough Care', 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/11/Peter-Howarth-2020-0171_Redacted.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation', 'coronername': 'Chris Morris', 'coronerarea': 'Greater Manchester South'}
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': True, 'care-home-health-related-deaths': True, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': True, 'other-related-deaths': False, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': False, 'railway-related-deaths': True, 'state-custody-related-deaths': False, 'suicide': True, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/malyun-karama/', 'title': 'Malyun Karama', 'published': '26 October 2020', 'timestamp': '2020-10-26T14:56:50+00:00', 'prevention-of-future-deaths': True, 'dateofreport': '21 August 2020', 'ref': '2020-0162', 'deceasedname': 'Malyun Karama', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Hospital death (Clinical procedure and medical management) related deaths', 'thisreportisbeingsentto': 'Royal Free Hospital', 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/10/Malyun-Karama-2020-0162_Redacted.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation', 'coronername': 'M E Hassell', 'coronerarea': 'Inner North London'}
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': True, 'care-home-health-related-deaths': True, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': True, 'other-related-deaths': False, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': False, 'railway-related-deaths': True, 'state-custody-related-deaths': False, 'suicide': True, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/ian-allen/', 'title': 'Ian Allen', 'published': '26 October 2020', 'timestamp': '2020-10-26T14:32:57+00:00', 'prevention-of-future-deaths': True, 'dateofreport': '17 August 2020', 'ref': '2020-0161', 'deceasedname': 'Ian Allen', 'coronersname': 'Andrew Harris', 'coronersarea': 'London Inner South', 'category': 'Care Home health deaths; Alcohol, drug and medication related deaths', 'thisreportisbeingsentto': 'Birmingham and Solihull Mental Health Foundation Trust; Department for Health and Social Care', 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2020/10/Ian-Allen-2020-0161.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2020/03/2020-0055-Response-from-South-London-and-Maudsley-NHS-Foundation-Redacted.pdf', 'responsetitle1': '2020-0055 Response from South London and Maudsley NHS Foundation Redacted', 'responseorg1': 'South London and Maudsley NHS Foundation', 'coronername': 'Louise Hunt', 'coronerarea': 'Birmingham and Solihull'}

# %%
print(scraperwiki.sql.select("count(*) from testrun2"))
# Out:
# [{'count(*)': 4}]

# %% [markdown]
# ## Export test results as CSV
#
# Let's export as a CSV just to see what it looks like outside the environment.

# %%
testresults = scraperwiki.sql.select("* from testrun2")
#Create a dataframe and assign the data to it
testresultsdf = pd.DataFrame(testresults)
#Print the first few rows (head)
print(testresultsdf.head())
#Export as a CSV file using the .to_csv function https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html
testresultsdf.to_csv('testresultsdf.csv')
# Out:
#    accident-at-work-and-health-and-safety-related-deaths  ...               coronerarea
# 0                                                  0      ...         Brighton and Hove
# 1                                                  0      ...  Greater Manchester South
# 2                                                  0      ...        Inner North London
# 3                                                  0      ...   Birmingham and Solihull
#
# [4 rows x 36 columns]

# %% [markdown]
# ## Running on the full 3220 pages
#
# Now that we've tested it on a few pages, we let it loose on all the pages. Chances are that older pages with different HTML may break it.

# %%
print(pageurls[213])
# Out:
# https://www.judiciary.uk/publication-jurisdiction/coroner/page/214

# %%
#Loop through those results urls
for i in pageurls[213:]:
  #On each one, scrape the links to the detail pages
  detailurls = scraperesultspage(i)
  #Loop through the list of links
  for i in detailurls:
    print(i)
    print
    testresults = scrapedetail(i)
    #Print
    print(testresults)
    scraperwiki.sql.save(['url'], testresults, table_name = "fullrun1")
# Out:
# https://www.judiciary.uk/publications/harry-mellor/
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': False, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': False, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': False, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/harry-mellor/', 'title': 'Harry Mellor', 'published': '22 October 2015', 'timestamp': '2015-10-22T11:33:37+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '22 October 2015', 'ref': '2015-0409', 'deceasedname': 'Harry Mellor', 'coronersname': 'Maria Mulrennan', 'coronersarea': 'Nottinghamshire', 'category': 'Hospital Death (Clinical Procedures and medical management) related deaths; Child Death (from 2015)', 'thisreportisbeingsentto': 'Public Health England; Department of Health; Nottinghamshire Safeguarding Children Board; General Medical Council; Nottingham City Clinical Commissioning Group', 'num_of_pdfs': 5, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2016/01/Mellor-2015-0409.pdf', 'responses': 4, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0409-Response-by-Department-of-Health.pdf', 'responsetitle1': '2015-0409 Response by Department of Health', 'responseorg1': ' Response by Department of Health', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/CCG-Response.pdf', 'responsetitle2': 'CCG Response', 'responseorg2': 'CCG Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/PHE-Response.pdf', 'responsetitle3': 'PHE Response', 'responseorg3': 'PHE Response', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/publications/diane-knight/
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': False, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': False, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': False, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/diane-knight/', 'title': 'Diane Knight', 'published': '22 October 2015', 'timestamp': '2015-10-22T11:24:56+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '22 October 2015', 'ref': '2015-0408', 'deceasedname': 'Diane Knight', 'coronersname': 'John Tomalin', 'coronersarea': 'Exeter and Greater Devon', 'category': 'Hospital Death (Clinical Procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Devon Partnership Trust', 'num_of_pdfs': 2, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2016/01/Knight-2015-0408.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2015/10/Diane-Knight-Response.pdf', 'responsetitle1': 'Diane Knight Response', 'responseorg1': 'Diane Knight Response', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/CCG-Response.pdf', 'responsetitle2': 'CCG Response', 'responseorg2': 'CCG Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/PHE-Response.pdf', 'responsetitle3': 'PHE Response', 'responseorg3': 'PHE Response', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/publications/david-baddeley/
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': False, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': False, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': False, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/david-baddeley/', 'title': 'David Baddeley', 'published': '21 October 2015', 'timestamp': '2015-10-21T15:36:46+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '21 October 2015', 'ref': '2015-0451', 'deceasedname': 'David Baddeley', 'coronersname': 'Joanne Kearsley', 'coronersarea': 'Manchester (South)', 'category': 'Hospital Death (Clinical Procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Greater Manchester NHS Area Team', 'num_of_pdfs': 2, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2016/06/Baddeley-2015-0451.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0451-Response.pdf', 'responsetitle1': '2015-0451 Response', 'responseorg1': ' Response', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/CCG-Response.pdf', 'responsetitle2': 'CCG Response', 'responseorg2': 'CCG Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/PHE-Response.pdf', 'responsetitle3': 'PHE Response', 'responseorg3': 'PHE Response', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/publications/samantha-beach/
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': False, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': False, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': False, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/samantha-beach/', 'title': 'Samantha Beach', 'published': '21 October 2015', 'timestamp': '2015-10-21T13:30:04+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '21 October 2015', 'ref': '2015-0413', 'deceasedname': 'Samantha Beach', 'coronersname': 'Katy Skerrett', 'coronersarea': 'Gloucestershire', 'category': 'Hospital Death (Clinical Procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Gloucestershire Hospitals NHS Trust', 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2016/01/Beach-2015-0413.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0451-Response.pdf', 'responsetitle1': '2015-0451 Response', 'responseorg1': ' Response', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/CCG-Response.pdf', 'responsetitle2': 'CCG Response', 'responseorg2': 'CCG Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/PHE-Response.pdf', 'responsetitle3': 'PHE Response', 'responseorg3': 'PHE Response', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/publications/dorothy-cooper/
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': False, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': False, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': False, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/dorothy-cooper/', 'title': 'Dorothy Cooper', 'published': '21 October 2015', 'timestamp': '2015-10-21T13:17:29+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '21 October 2015', 'ref': '2015-0412', 'deceasedname': 'Dorothy Cooper', 'coronersname': 'Nicola Mundy', 'coronersarea': 'South Yorkshire (East)', 'category': 'Hospital Death (Clinical Procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Mid Yorkshire NHS Trust; Leeds Teaching Hospitals NHS Trust', 'num_of_pdfs': 4, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2016/01/Cooper-2015-04122.pdf', 'responses': 3, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2016/01/Cooper-2015-0412.pdf', 'responsetitle1': 'Cooper 2015-0412', 'responseorg1': 'Cooper ', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response.pdf', 'responsetitle2': '2015-0412 Response', 'responseorg2': ' Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response2.pdf', 'responsetitle3': '2015-0412 Response(2)', 'responseorg3': ' Response(2)', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/publications/erich-speilmann/
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': False, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': False, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/erich-speilmann/', 'title': 'Erich Speilmann', 'published': '20 October 2015', 'timestamp': '2015-10-20T14:16:53+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '20 October 2015', 'ref': '2015-0389', 'deceasedname': 'Erich Speilmann', 'coronersname': 'Caroline Beasley-Murray', 'coronersarea': 'Essex', 'category': 'Road (Highways Safety) related deaths', 'thisreportisbeingsentto': 'Essex Highways Agency', 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2016/02/Spielmann-2015-0389.pdf', 'responses': 3, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2016/01/Cooper-2015-0412.pdf', 'responsetitle1': 'Cooper 2015-0412', 'responseorg1': 'Cooper ', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response.pdf', 'responsetitle2': '2015-0412 Response', 'responseorg2': ' Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response2.pdf', 'responsetitle3': '2015-0412 Response(2)', 'responseorg3': ' Response(2)', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/wp-content/uploads/2013/09/guidance-no-21-translators-interpreters.pdf
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': False, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': False, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/wp-content/uploads/2013/09/guidance-no-21-translators-interpreters.pdf', 'title': 'Erich Speilmann', 'published': '20 October 2015', 'timestamp': '2015-10-20T14:16:53+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '20 October 2015', 'ref': '2015-0389', 'deceasedname': 'Erich Speilmann', 'coronersname': 'Caroline Beasley-Murray', 'coronersarea': 'Essex', 'category': 'Road (Highways Safety) related deaths', 'thisreportisbeingsentto': 'Essex Highways Agency', 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2016/02/Spielmann-2015-0389.pdf', 'responses': 3, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2016/01/Cooper-2015-0412.pdf', 'responsetitle1': 'Cooper 2015-0412', 'responseorg1': 'Cooper ', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response.pdf', 'responsetitle2': '2015-0412 Response', 'responseorg2': ' Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response2.pdf', 'responsetitle3': '2015-0412 Response(2)', 'responseorg3': ' Response(2)', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/wp-content/uploads/2013/09/guidance-no-20-core-compentencies-assistant-coroners.pdf
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': False, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': False, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/wp-content/uploads/2013/09/guidance-no-20-core-compentencies-assistant-coroners.pdf', 'title': 'Erich Speilmann', 'published': '20 October 2015', 'timestamp': '2015-10-20T14:16:53+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '20 October 2015', 'ref': '2015-0389', 'deceasedname': 'Erich Speilmann', 'coronersname': 'Caroline Beasley-Murray', 'coronersarea': 'Essex', 'category': 'Road (Highways Safety) related deaths', 'thisreportisbeingsentto': 'Essex Highways Agency', 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2016/02/Spielmann-2015-0389.pdf', 'responses': 3, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2016/01/Cooper-2015-0412.pdf', 'responsetitle1': 'Cooper 2015-0412', 'responseorg1': 'Cooper ', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response.pdf', 'responsetitle2': '2015-0412 Response', 'responseorg2': ' Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response2.pdf', 'responsetitle3': '2015-0412 Response(2)', 'responseorg3': ' Response(2)', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/wp-content/uploads/2013/09/guidance-no-19-mentors.pdf
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': False, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': False, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/wp-content/uploads/2013/09/guidance-no-19-mentors.pdf', 'title': 'Erich Speilmann', 'published': '20 October 2015', 'timestamp': '2015-10-20T14:16:53+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '20 October 2015', 'ref': '2015-0389', 'deceasedname': 'Erich Speilmann', 'coronersname': 'Caroline Beasley-Murray', 'coronersarea': 'Essex', 'category': 'Road (Highways Safety) related deaths', 'thisreportisbeingsentto': 'Essex Highways Agency', 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2016/02/Spielmann-2015-0389.pdf', 'responses': 3, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2016/01/Cooper-2015-0412.pdf', 'responsetitle1': 'Cooper 2015-0412', 'responseorg1': 'Cooper ', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response.pdf', 'responsetitle2': '2015-0412 Response', 'responseorg2': ' Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response2.pdf', 'responsetitle3': '2015-0412 Response(2)', 'responseorg3': ' Response(2)', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/publications/william-abel/
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': False, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': False, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/william-abel/', 'title': 'William Abel', 'published': '20 October 2015', 'timestamp': '2015-10-20T11:00:45+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '20 October 2015', 'ref': '2015-0406', 'deceasedname': 'William Abel', 'coronersname': 'Lydia Brown', 'coronersarea': 'Leicester City and Leicestershire South', 'category': 'Hospital Death (Clinical Procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Leicester Partnership NHS Trust', 'num_of_pdfs': 2, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2016/01/Abel-2015-0406.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0406-Response-by-Leicester-Partnership-NHS-Trust.pdf', 'responsetitle1': '2015-0406 Response by Leicester Partnership NHS Trust', 'responseorg1': ' Response by Leicester Partnership NHS Trust', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response.pdf', 'responsetitle2': '2015-0412 Response', 'responseorg2': ' Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response2.pdf', 'responsetitle3': '2015-0412 Response(2)', 'responseorg3': ' Response(2)', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/publications/kyle-hull/
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': False, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': True, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/kyle-hull/', 'title': 'Kyle Hull', 'published': '19 October 2015', 'timestamp': '2015-10-19T11:51:06+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '19 October 2015', 'ref': '2015-0379', 'deceasedname': 'Kyle Hull', 'coronersname': 'Andrew Tweddle', 'coronersarea': 'County Durham and Darlington', 'category': 'Other related deaths; Child Death (from 2015)', 'thisreportisbeingsentto': 'Darlington Cattle Mart', 'num_of_pdfs': 2, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2015/12/Hull-2015-0379.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0379-response.pdf', 'responsetitle1': '2015-0379 response', 'responseorg1': ' response', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response.pdf', 'responsetitle2': '2015-0412 Response', 'responseorg2': ' Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response2.pdf', 'responsetitle3': '2015-0412 Response(2)', 'responseorg3': ' Response(2)', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/publications/vasilis-ktorakis/
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': False, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': True, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/vasilis-ktorakis/', 'title': 'Vasilis Ktorakis', 'published': '19 October 2015', 'timestamp': '2015-10-19T11:36:07+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '19 October 2015', 'ref': '2015-0377', 'deceasedname': 'Vasilis Ktorakis', 'coronersname': 'ME Hassell', 'coronersarea': 'London Inner (North)', 'category': 'Hospital Death (Clinical Procedures and medical management) related deaths; Child Death (from 2015)', 'thisreportisbeingsentto': 'Whittington Hospital NHS Trust', 'num_of_pdfs': 3, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2015/12/Ktorakis-2015-0377.pdf', 'responses': 2, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0377-Vasilis-KtorakisR_Redacted.pdf', 'responsetitle1': '2015-0377 Vasilis Ktorakis(R)_Redacted', 'responseorg1': ' Vasilis Ktorakis(R)_Redacted', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0377-Response.pdf', 'responsetitle2': '2015-0377 Response', 'responseorg2': ' Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response2.pdf', 'responsetitle3': '2015-0412 Response(2)', 'responseorg3': ' Response(2)', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/publications/adrian-smith/
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': False, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': False, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': True, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/adrian-smith/', 'title': 'Adrian Smith', 'published': '16 October 2015', 'timestamp': '2015-10-16T15:17:32+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '16 October 2015', 'ref': '2015-0378', 'deceasedname': 'Adrian Smith', 'coronersname': 'Louise Hunt', 'coronersarea': 'Birmingham and Solihull', 'category': 'Hospital Death (Clinical Procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Heart of England NHS Foundation Trust; NHS England', 'num_of_pdfs': 2, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2015/12/Smith-2015-0378.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0378-Response.pdf', 'responsetitle1': '2015-0378 Response', 'responseorg1': ' Response', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0377-Response.pdf', 'responsetitle2': '2015-0377 Response', 'responseorg2': ' Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response2.pdf', 'responsetitle3': '2015-0412 Response(2)', 'responseorg3': ' Response(2)', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/publications/caroline-robey/
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': False, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': True, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': True, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/caroline-robey/', 'title': 'Caroline Robey', 'published': '16 October 2015', 'timestamp': '2015-10-16T11:06:43+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '16 October 2015', 'ref': '2015-0376', 'deceasedname': 'Caroline Robey', 'coronersname': 'Lydia Brown', 'coronersarea': 'Leicester City and Leicestershire South', 'category': 'Community health care and emergency services related deaths', 'thisreportisbeingsentto': 'East Midlands Ambulance Service; NHS England', 'num_of_pdfs': 2, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2015/12/Robey-2015-0376.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2015/10/ROBEY-Responses.pdf', 'responsetitle1': 'ROBEY Responses', 'responseorg1': 'ROBEY Responses', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0377-Response.pdf', 'responsetitle2': '2015-0377 Response', 'responseorg2': ' Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response2.pdf', 'responsetitle3': '2015-0412 Response(2)', 'responseorg3': ' Response(2)', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/publications/william-tolen/
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': True, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': True, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': True, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/william-tolen/', 'title': 'William Tolen', 'published': '15 October 2015', 'timestamp': '2015-10-15T11:13:10+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '15 October 2015', 'ref': '2015-0407', 'deceasedname': 'William Tolen', 'coronersname': 'John Pollard', 'coronersarea': 'Manchester (South)', 'category': 'Care Home Health related deaths', 'thisreportisbeingsentto': 'Shawe Lodge', 'num_of_pdfs': 2, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2016/01/Tolen-2015-0407.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2015/10/William-Tolen-Response.pdf', 'responsetitle1': 'William Tolen Response', 'responseorg1': 'William Tolen Response', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0377-Response.pdf', 'responsetitle2': '2015-0377 Response', 'responseorg2': ' Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response2.pdf', 'responsetitle3': '2015-0412 Response(2)', 'responseorg3': ' Response(2)', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/publications/alan-tear/
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': True, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': True, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': True, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/alan-tear/', 'title': 'Alan Tear', 'published': '14 October 2015', 'timestamp': '2015-10-14T16:32:07+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '14 October 2015', 'ref': '2015-0373', 'deceasedname': 'Alan Tear', 'coronersname': 'Lydia Brown', 'coronersarea': 'Leicester City and Leicestershire South', 'category': 'Hospital Death (Clinical Procedures and medical management) related deaths', 'thisreportisbeingsentto': 'University Hospitals of Leicester NHS Trust', 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2015/12/Tear-2015-0373.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2015/10/William-Tolen-Response.pdf', 'responsetitle1': 'William Tolen Response', 'responseorg1': 'William Tolen Response', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0377-Response.pdf', 'responsetitle2': '2015-0377 Response', 'responseorg2': ' Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response2.pdf', 'responsetitle3': '2015-0412 Response(2)', 'responseorg3': ' Response(2)', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/publications/nathaniel-phillips/
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': False, 'care-home-health-related-deaths': True, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': True, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': True, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/nathaniel-phillips/', 'title': 'Nathaniel Phillips', 'published': '13 October 2015', 'timestamp': '2015-10-13T17:09:24+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '13 October 2015', 'ref': '2015-0375', 'deceasedname': 'Nathaniel Phillips', 'coronersname': 'Joanne Kearsley', 'coronersarea': 'Manchester (South)', 'category': 'Community health care and emergency services related deaths', 'thisreportisbeingsentto': 'Department of Health', 'num_of_pdfs': 2, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2015/12/Phillips-2015-0375.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0375-Response-by-Department-of-Health.pdf', 'responsetitle1': '2015-0375 Response by Department of Health', 'responseorg1': ' Response by Department of Health', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0377-Response.pdf', 'responsetitle2': '2015-0377 Response', 'responseorg2': ' Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response2.pdf', 'responsetitle3': '2015-0412 Response(2)', 'responseorg3': ' Response(2)', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/publications/catherine-findlay/
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': True, 'care-home-health-related-deaths': True, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': True, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': True, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/catherine-findlay/', 'title': 'Catherine Findlay', 'published': '13 October 2015', 'timestamp': '2015-10-13T16:15:15+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '13 October 2015', 'ref': '2015-0372', 'deceasedname': 'Catherine Findlay', 'coronersname': 'Simon Jones', 'coronersarea': 'Manchester (West)', 'category': 'Alcohol, drug and medication related deaths', 'thisreportisbeingsentto': 'The Home Office; The Minister of State for Crime Prevention; The Advisory Council on the Misuse of Drugs', 'num_of_pdfs': 2, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2015/12/Findlay-2015-0372.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0372-Response.pdf', 'responsetitle1': '2015-0372 Response', 'responseorg1': ' Response', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0377-Response.pdf', 'responsetitle2': '2015-0377 Response', 'responseorg2': ' Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response2.pdf', 'responsetitle3': '2015-0412 Response(2)', 'responseorg3': ' Response(2)', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/publications/mrs-withers/
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': True, 'care-home-health-related-deaths': True, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': True, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': True, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/mrs-withers/', 'title': 'Mrs Withers', 'published': '12 October 2015', 'timestamp': '2015-10-12T14:34:40+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '12 October 2015', 'ref': '2015-0371', 'deceasedname': 'Mrs Withers', 'coronersname': 'Hassan Shah', 'coronersarea': 'Northampton', 'category': 'Hospital Death (Clinical Procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Kettering General Hospital NHS Trust', 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2016/01/Withers-2015-0371.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0372-Response.pdf', 'responsetitle1': '2015-0372 Response', 'responseorg1': ' Response', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0377-Response.pdf', 'responsetitle2': '2015-0377 Response', 'responseorg2': ' Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response2.pdf', 'responsetitle3': '2015-0412 Response(2)', 'responseorg3': ' Response(2)', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/publications/patrick-carrick/
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': True, 'care-home-health-related-deaths': True, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': True, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': True, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/patrick-carrick/', 'title': 'Patrick Carrick', 'published': '9 October 2015', 'timestamp': '2015-10-09T17:02:11+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '9 October 2015', 'ref': '2015-0374', 'deceasedname': 'Patrick Carrick', 'coronersname': 'Karen Dilks', 'coronersarea': 'Newcastle Upon Tyne', 'category': 'Hospital Death (Clinical Procedures and medical management) related deaths', 'thisreportisbeingsentto': 'North Tyneside General Hospital', 'num_of_pdfs': 2, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2015/12/Carrick-2015-0374.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0374-Response-by-Northumbria-Health-Care-NHS-Trust.pdf', 'responsetitle1': '2015-0374 Response by Northumbria Health Care NHS Trust', 'responseorg1': ' Response by Northumbria Health Care NHS Trust', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0377-Response.pdf', 'responsetitle2': '2015-0377 Response', 'responseorg2': ' Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response2.pdf', 'responsetitle3': '2015-0412 Response(2)', 'responseorg3': ' Response(2)', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/publications/suzanne-greenwood/
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': True, 'care-home-health-related-deaths': True, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': True, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': True, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/suzanne-greenwood/', 'title': 'Suzanne Greenwood', 'published': '9 October 2015', 'timestamp': '2015-10-09T12:42:22+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '9 October 2015', 'ref': '2015-0370', 'deceasedname': 'Suzanne Greenwood', 'coronersname': 'Alan Walsh', 'coronersarea': 'Manchester (West)', 'category': 'Hospital Death (Clinical Procedures and medical management) related deaths', 'thisreportisbeingsentto': 'The Priory Hospital', 'num_of_pdfs': 2, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2015/12/Greenwood-2015-0370.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0370-Response-by-The-Priory_Redacted.pdf', 'responsetitle1': '2015-0370 Response by The Priory_Redacted', 'responseorg1': ' Response by The Priory_Redacted', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0377-Response.pdf', 'responsetitle2': '2015-0377 Response', 'responseorg2': ' Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response2.pdf', 'responsetitle3': '2015-0412 Response(2)', 'responseorg3': ' Response(2)', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/publications/maureen-chatterley/
# {'accident-at-work-and-health-and-safety-related-deaths': False, 'alcohol-drug-and-medication-related-deaths': True, 'care-home-health-related-deaths': True, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': True, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': False, 'other-related-deaths': True, 'police-related-deaths': False, 'product-related-deaths': False, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': False, 'state-custody-related-deaths': False, 'suicide': False, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/maureen-chatterley/', 'title': 'Maureen Chatterley', 'published': '8 October 2015', 'timestamp': '2015-10-08T15:44:35+01:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '8 October 2015', 'ref': '2015-0404', 'deceasedname': 'Maureen Chatterley', 'coronersname': 'Alan Walsh', 'coronersarea': 'Manchester (West)', 'category': 'Hospital Death (Clinical Procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Royal Bolton Hospital', 'num_of_pdfs': 2, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2016/01/Chatterley-2015-04041.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0404-Response-by-Bolton-NHS-Trust.pdf', 'responsetitle1': '2015-0404 Response by Bolton NHS Trust', 'responseorg1': ' Response by Bolton NHS Trust', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0377-Response.pdf', 'responsetitle2': '2015-0377 Response', 'responseorg2': ' Response', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2015/10/2015-0412-Response2.pdf', 'responsetitle3': '2015-0412 Response(2)', 'responseorg3': ' Response(2)', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2015/10/GMC-Response.pdf', 'responsetitle4': 'GMC Response', 'responseorg4': 'GMC Response'}
# https://www.judiciary.uk/publications/solomon-bealey/
# ...
# https://www.judiciary.uk/publications/clive-gould/
# {'accident-at-work-and-health-and-safety-related-deaths': True, 'alcohol-drug-and-medication-related-deaths': True, 'care-home-health-related-deaths': True, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': True, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': True, 'other-related-deaths': True, 'police-related-deaths': True, 'product-related-deaths': True, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': True, 'state-custody-related-deaths': True, 'suicide': True, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/clive-gould/', 'title': 'Clive Gould', 'published': '16 December 2013', 'timestamp': '2013-12-16T09:54:17+00:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '16 December 2013', 'ref': '2013-0357', 'deceasedname': 'Clive Gould', 'coronersname': 'Nicholas Graham', 'coronersarea': 'Oxfordshire', 'category': 'Community health care and emergency services related deaths', 'thisreportisbeingsentto': 'Food Standards Agency; Department for Education; Ofsted', 'num_of_pdfs': 2, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2017/11/Clive_Gould-2013-0357.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2017/11/2013-0357-Response-by-South-Central-Ambulance-Service.pdf', 'responsetitle1': '2013-0357 Response by South Central Ambulance Service', 'responseorg1': ' Response by South Central Ambulance Service', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2013/12/2013-0277-Response-by-NHS-Blood-and-Transplant.pdf', 'responsetitle2': '2013-0277 Response by NHS Blood and Transplant', 'responseorg2': ' Response by NHS Blood and Transplant', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2013/12/2013-0371-Response-by-West-Mercia-Police.pdf', 'responsetitle3': '2013-0371 Response by West Mercia Police', 'responseorg3': ' Response by West Mercia Police', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2014/01/2014-0039-Response-by-Royal-Pharmaceutical-Society.pdf', 'responsetitle4': '2014-0039 Response by Royal Pharmaceutical Society', 'responseorg4': ' Response by Royal Pharmaceutical Society', 'service-personnel-related-deaths': True, 'annual-report': True, 'responseurl5': 'https://www.judiciary.uk/wp-content/uploads/2014/05/2014-0182-Response-by-ACPO.pdf', 'responsetitle5': '2014-0182 Response by ACPO', 'responseorg5': ' Response by ACPO', 'https://www.judiciary.uk/publication-type/reports-and-reviews': True, 'coroners': 'Area', 'nameofdeceased': 'Jerome Gonnet', 'nameofcoroner': 'Clare Bailey', 'coronerarea': 'Teesside', 'deceased’sname': 'Anne Whitworth', 'coroner’sname': 'David Hinchliff', 'coroner’sarea': 'West Yorkshire (East)', 'https://www.judiciary.uk/publication-type/guidance': True}
# https://www.judiciary.uk/publications/sarah-shepherd/
# {'accident-at-work-and-health-and-safety-related-deaths': True, 'alcohol-drug-and-medication-related-deaths': True, 'care-home-health-related-deaths': True, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': True, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': True, 'other-related-deaths': True, 'police-related-deaths': True, 'product-related-deaths': True, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': True, 'state-custody-related-deaths': True, 'suicide': True, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/sarah-shepherd/', 'title': 'Sarah Shepherd', 'published': '13 December 2013', 'timestamp': '2013-12-13T21:45:29+00:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '16 December 2013', 'ref': '2013-0359', 'deceasedname': 'Sarah Shepherd', 'coronersname': 'Alison Hewitt', 'coronersarea': 'Surrey', 'category': 'Hospital Death (Clinical Procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Food Standards Agency; Department for Education; Ofsted', 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2019/10/Sarah-Shepherd-2013-0556_Redacted.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2017/11/2013-0357-Response-by-South-Central-Ambulance-Service.pdf', 'responsetitle1': '2013-0357 Response by South Central Ambulance Service', 'responseorg1': ' Response by South Central Ambulance Service', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2013/12/2013-0277-Response-by-NHS-Blood-and-Transplant.pdf', 'responsetitle2': '2013-0277 Response by NHS Blood and Transplant', 'responseorg2': ' Response by NHS Blood and Transplant', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2013/12/2013-0371-Response-by-West-Mercia-Police.pdf', 'responsetitle3': '2013-0371 Response by West Mercia Police', 'responseorg3': ' Response by West Mercia Police', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2014/01/2014-0039-Response-by-Royal-Pharmaceutical-Society.pdf', 'responsetitle4': '2014-0039 Response by Royal Pharmaceutical Society', 'responseorg4': ' Response by Royal Pharmaceutical Society', 'service-personnel-related-deaths': True, 'annual-report': True, 'responseurl5': 'https://www.judiciary.uk/wp-content/uploads/2014/05/2014-0182-Response-by-ACPO.pdf', 'responsetitle5': '2014-0182 Response by ACPO', 'responseorg5': ' Response by ACPO', 'https://www.judiciary.uk/publication-type/reports-and-reviews': True, 'coroners': 'Area', 'nameofdeceased': 'Jerome Gonnet', 'nameofcoroner': 'Clare Bailey', 'coronerarea': 'Teesside', 'deceased’sname': 'Anne Whitworth', 'coroner’sname': 'David Hinchliff', 'coroner’sarea': 'West Yorkshire (East)', 'https://www.judiciary.uk/publication-type/guidance': True}
# https://www.judiciary.uk/publications/stephanie-daniels/
# {'accident-at-work-and-health-and-safety-related-deaths': True, 'alcohol-drug-and-medication-related-deaths': True, 'care-home-health-related-deaths': True, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': True, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': True, 'other-related-deaths': True, 'police-related-deaths': True, 'product-related-deaths': True, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': True, 'state-custody-related-deaths': True, 'suicide': True, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/stephanie-daniels/', 'title': 'Stephanie Daniels', 'published': '13 December 2013', 'timestamp': '2013-12-13T20:51:24+00:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '13 December 2013', 'ref': '2013-0353', 'deceasedname': 'Stephanie Daniels', 'coronersname': 'Nigel Meadows', 'coronersarea': 'Manchester City', 'category': 'Hospital Death (Clinical Procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Food Standards Agency; Department for Education; Ofsted', 'num_of_pdfs': 4, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2014/05/Daniels-2013-0353.pdf', 'responses': 3, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2014/05/2013-0353-Response-by-Manchester-Mental-Health-NHS.pdf', 'responsetitle1': '2013-0353 Response by Manchester Mental Health NHS', 'responseorg1': ' Response by Manchester Mental Health NHS', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2013/12/2013-0353-Response-by-Manchester-Clinical-Commissioning-Groups.pdf', 'responsetitle2': '2013-0353 Response by Manchester Clinical Commissioning Groups', 'responseorg2': ' Response by Manchester Clinical Commissioning Groups', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2013/12/2013-0353-Response-by-Department-of-Health.pdf', 'responsetitle3': '2013-0353 Response by Department of Health', 'responseorg3': ' Response by Department of Health', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2014/01/2014-0039-Response-by-Royal-Pharmaceutical-Society.pdf', 'responsetitle4': '2014-0039 Response by Royal Pharmaceutical Society', 'responseorg4': ' Response by Royal Pharmaceutical Society', 'service-personnel-related-deaths': True, 'annual-report': True, 'responseurl5': 'https://www.judiciary.uk/wp-content/uploads/2014/05/2014-0182-Response-by-ACPO.pdf', 'responsetitle5': '2014-0182 Response by ACPO', 'responseorg5': ' Response by ACPO', 'https://www.judiciary.uk/publication-type/reports-and-reviews': True, 'coroners': 'Area', 'nameofdeceased': 'Jerome Gonnet', 'nameofcoroner': 'Clare Bailey', 'coronerarea': 'Teesside', 'deceased’sname': 'Anne Whitworth', 'coroner’sname': 'David Hinchliff', 'coroner’sarea': 'West Yorkshire (East)', 'https://www.judiciary.uk/publication-type/guidance': True}
# https://www.judiciary.uk/publications/rosemary-bronwyn-ferguson/
# {'accident-at-work-and-health-and-safety-related-deaths': True, 'alcohol-drug-and-medication-related-deaths': True, 'care-home-health-related-deaths': True, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': True, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': True, 'other-related-deaths': True, 'police-related-deaths': True, 'product-related-deaths': True, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': True, 'state-custody-related-deaths': True, 'suicide': True, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/rosemary-bronwyn-ferguson/', 'title': 'Rosemary Bronwyn Ferguson', 'published': '12 December 2013', 'timestamp': '2013-12-12T12:55:06+00:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '12 December 2013', 'ref': '2013-0365', 'deceasedname': 'Rosemary Brownyn Ferguson', 'coronersname': 'Geoffrey Saul', 'coronersarea': 'South Yorkshire (East)', 'category': 'Hospital Death (Clinical Procedures and medical management) related deaths', 'thisreportisbeingsentto': 'Food Standards Agency; Department for Education; Ofsted', 'num_of_pdfs': 1, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2014/05/Ferguson-2013-0365.pdf', 'responses': 3, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2014/05/2013-0353-Response-by-Manchester-Mental-Health-NHS.pdf', 'responsetitle1': '2013-0353 Response by Manchester Mental Health NHS', 'responseorg1': ' Response by Manchester Mental Health NHS', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2013/12/2013-0353-Response-by-Manchester-Clinical-Commissioning-Groups.pdf', 'responsetitle2': '2013-0353 Response by Manchester Clinical Commissioning Groups', 'responseorg2': ' Response by Manchester Clinical Commissioning Groups', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2013/12/2013-0353-Response-by-Department-of-Health.pdf', 'responsetitle3': '2013-0353 Response by Department of Health', 'responseorg3': ' Response by Department of Health', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2014/01/2014-0039-Response-by-Royal-Pharmaceutical-Society.pdf', 'responsetitle4': '2014-0039 Response by Royal Pharmaceutical Society', 'responseorg4': ' Response by Royal Pharmaceutical Society', 'service-personnel-related-deaths': True, 'annual-report': True, 'responseurl5': 'https://www.judiciary.uk/wp-content/uploads/2014/05/2014-0182-Response-by-ACPO.pdf', 'responsetitle5': '2014-0182 Response by ACPO', 'responseorg5': ' Response by ACPO', 'https://www.judiciary.uk/publication-type/reports-and-reviews': True, 'coroners': 'Area', 'nameofdeceased': 'Jerome Gonnet', 'nameofcoroner': 'Clare Bailey', 'coronerarea': 'Teesside', 'deceased’sname': 'Anne Whitworth', 'coroner’sname': 'David Hinchliff', 'coroner’sarea': 'West Yorkshire (East)', 'https://www.judiciary.uk/publication-type/guidance': True}
# https://www.judiciary.uk/publications/william-mccourt/
# {'accident-at-work-and-health-and-safety-related-deaths': True, 'alcohol-drug-and-medication-related-deaths': True, 'care-home-health-related-deaths': True, 'child-deat': False, 'community-health-care-and-emergency-services-related-deaths': True, 'emergency-services-related-deaths-prevention-of-future-deaths': False, 'hospital-death-clinical-procedures-and-medical-management-related-deaths': True, 'mental-health-related-deaths': True, 'other-related-deaths': True, 'police-related-deaths': True, 'product-related-deaths': True, 'road-highways-safety-related-deaths': True, 'railway-related-deaths': True, 'state-custody-related-deaths': True, 'suicide': True, 'wales-pfd-reports-related-deaths': False, 'url': 'https://www.judiciary.uk/publications/william-mccourt/', 'title': 'William McCourt', 'published': '12 December 2013', 'timestamp': '2013-12-12T10:59:19+00:00', 'prevention-of-future-deaths': True, 'child-death': True, 'dateofreport': '12 December 2013', 'ref': '2013-0383', 'deceasedname': 'William McCourt', 'coronersname': 'Robert Turnbull', 'coronersarea': 'North Yorkshire (West)', 'category': 'Other related deaths', 'thisreportisbeingsentto': 'Food Standards Agency; Department for Education; Ofsted', 'num_of_pdfs': 2, 'pdflink': 'https://www.judiciary.uk/wp-content/uploads/2015/03/McCourt-2013-0383.pdf', 'responses': 1, 'responseurl1': 'https://www.judiciary.uk/wp-content/uploads/2015/03/2013-0383-Response-by-North-Yorkshire-County-Council.pdf', 'responsetitle1': '2013-0383 Response by North Yorkshire County Council', 'responseorg1': ' Response by North Yorkshire County Council', 'responseurl2': 'https://www.judiciary.uk/wp-content/uploads/2013/12/2013-0353-Response-by-Manchester-Clinical-Commissioning-Groups.pdf', 'responsetitle2': '2013-0353 Response by Manchester Clinical Commissioning Groups', 'responseorg2': ' Response by Manchester Clinical Commissioning Groups', 'responseurl3': 'https://www.judiciary.uk/wp-content/uploads/2013/12/2013-0353-Response-by-Department-of-Health.pdf', 'responsetitle3': '2013-0353 Response by Department of Health', 'responseorg3': ' Response by Department of Health', 'responseurl4': 'https://www.judiciary.uk/wp-content/uploads/2014/01/2014-0039-Response-by-Royal-Pharmaceutical-Society.pdf', 'responsetitle4': '2014-0039 Response by Royal Pharmaceutical Society', 'responseorg4': ' Response by Royal Pharmaceutical Society', 'service-personnel-related-deaths': True, 'annual-report': True, 'responseurl5': 'https://www.judiciary.uk/wp-content/uploads/2014/05/2014-0182-Response-by-ACPO.pdf', 'responsetitle5': '2014-0182 Response by ACPO', 'responseorg5': ' Response by ACPO', 'https://www.judiciary.uk/publication-type/reports-and-reviews': True, 'coroners': 'Area', 'nameofdeceased': 'Jerome Gonnet', 'nameofcoroner': 'Clare Bailey', 'coronerarea': 'Teesside', 'deceased’sname': 'Anne Whitworth', 'coroner’sname': 'David Hinchliff', 'coroner’sarea': 'West Yorkshire (East)', 'https://www.judiciary.uk/publication-type/guidance': True}

# %% [markdown]
# ## Export the results
#
# Now export as a CSV.

# %%
fullresults = scraperwiki.sql.select("* from fullrun1")
#Create a dataframe and assign the data to it
fullresultsdf = pd.DataFrame(fullresults)
#Print the first few rows (head)
print(fullresultsdf.head())
#Export as a CSV file using the .to_csv function https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html
fullresultsdf.to_csv('fullresultsdf.csv')
# Out:
#    accident-at-work-and-health-and-safety-related-deaths  ...  coroner’sarea
# 0                                                  0      ...           None
# 1                                                  0      ...           None
# 2                                                  0      ...           None
# 3                                                  0      ...           None
# 4                                                  0      ...           None
#
# [5 rows x 87 columns]

# %%
scraperwiki.sql.select("count(*) from fullrun1")
# Out:
# [{'count(*)': 2136}]
